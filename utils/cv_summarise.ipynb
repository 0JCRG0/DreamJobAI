# %%
import os
import openai
from dotenv import load_dotenv
import pandas as pd
import pretty_errors

load_dotenv('.env')
openai.api_key = os.getenv("OPENAI_API_KEY")

MODEL= "gpt-3.5-turbo-16k"
#MODEL = "gpt-3.5-turbo"

# %%
#job_description = """Hey there Were AKKO  a venture funded  fastgrowing insurtech company with a passionate solutionforward and collaborative team focused on disrupting the device protection space Our mission is simple  Leveraging technology to make protecting peoples tech easier and more affordable Most peoples lives have become techcentric and AKKO provides customers with peace of mind that their tech is safe guarded in a transparent and seamless way Backed by amazing investors such as Mundi Fika and Pear we are just getting started THE DAYTODAY Develop and manage data systems and databases Extract data from primary and secondary sources and removing corrupted data Establish KPIs that provide actionable insights Use data to analyze trends to help inform business policies and decisions Collaborate with engineers and developers to develop and streamline data governance strategies Ensure data is accurate and highquality Analyze data for trends and patterns and interpret data with a clear objective in mind Communicate analytic solutions to stakeholders and implement improvements and solutions WHAT MAKES YOU QUALIFIED Minimum one year experience working as a data analyst or similar role preferably for a startup with a bachelors degree in Statistics Computer Science Mathematics or equivalent practical experience Knowledge of relational and nonrelational NoSQL databases Python NumPy SciPy or R for statistical analysis Data visualization Looker Studio Power BI Tableau Pythons Matplotlib and Seaborn or similar Proficiency in Excel Actuarial knowledge or experience is a plus All around team player fast and selflearning individual Proactive and solutionforward bias for action Ability to drive forward work independently while communicating and working across functions Passion for data Experience working on highscale productiongrade projects WHY YOULL LOVE IT HERE Unlimited vacation and paid sick time Competitive health benefits including medical dental and vision insurance Robust 401k program  to invest in your future Monthly wellness stipend eg gym yoga meditation etc  we value your wellbeing Monthly treat yourself stipend  dinner on us Remote workspace stipend  Work from home or from a shared workspace  you decide Paid volunteer time  giving back to our community is important to us Annual learning credit explore personal interests that excite you and so much more The base salary for this position ranges from 65000 to 100000 Compensation varies based on jobrelated factors including business needs experience level of responsibility and qualifications WHAT ELSE ARE WE LOOKING FOR Our team is fostered around our core values Collaborate Work together to be more effective lift up others and win together Aim High Set ambitious goals Embrace Diversity Seek different perspectives bring our true self to work Customer Love Serve the end user and listen to them Nurture Empathy Listen and strive to truly understand others Take Action Be proactive be an owner value speed Maintain Integrity Build the AKKO you are proud to work at Data Driven Use data to iterate find truth CCPA disclosure notice at getakkocomlegal"""

# %%
delimiters = "####"

system_query = f""" 

Your task is to extract relevant information from a candidate's CV, to find suitable job openings./

Extract relevant information from the candidate's CV, delimited by {delimiters} characters, in at most 200 words. /

Extract any relevant information about qualifications, previous job titles, /
responsibilities/key duties, skills and other relevant achivements /
(such as publications, conferences, projects, awards, etc.). /

Use the following format:

Qualifications:
Previous job titles:
Responsibilities/Key Duties:
Skills: 
Other Achivements:

"""
"""
Your task is to summarise a candidate's CV, to find matching job openings./

Summarise the candidate's CV, delimited by {delimiters} characters, in at most 200 words. /

Focus on any relevant information about qualifications, previous job titles, /
responsibilities/key duties, skills and other relevant achivements /
(such as publications, conferences, projects, awards, etc.). /

Use the following format:

Qualifications:
Previous job titles:
Responsibilities/Key Duties:
Skills: 
Other Achivements:
"""

"""
Job Opening: {delimiters}{job_description}{delimiters}

"""
assistant_query=""" Remember to think step by step.
"""

# %%
def summarise_job(job_description):
    response = openai.ChatCompletion.create(
        messages=[
            {'role': 'user', 'content': system_query},
            {'role': 'user', 'content': f"CV: {delimiters}{job_description}{delimiters}"},
        ],
        model=MODEL,
        temperature=0,
        max_tokens=4000
    )
    response_message = response['choices'][0]['message']['content']
    total_cost = 0
    prompt_tokens = response['usage']['prompt_tokens']
    completion_tokens = response['usage']['completion_tokens']
    print(f"\nSUMMARISE JOBS FUNCTION\n", f"\nPROMPT TOKENS USED:{prompt_tokens}\n", f"COMPLETION TOKENS USED:{completion_tokens}\n" )
    #Approximate cost
    if MODEL == "gpt-3.5-turbo":
        prompt_cost = round((prompt_tokens / 1000) * 0.0015, 3)
        completion_cost = round((completion_tokens / 1000) * 0.002, 3)
        total_cost = prompt_cost + completion_cost
        print(f"COST FOR SUMMARISING: ${total_cost} USD")
    elif MODEL == "gpt-3.5-turbo-16k":
        prompt_cost = round((prompt_tokens / 1000) * 0.003, 3)
        completion_cost = round((completion_tokens / 1000) * 0.004, 3)
        total_cost = prompt_cost + completion_cost
        print(f"COST FOR SUMMARISING: ${total_cost} USD")
    return response_message, total_cost

# %%
job_description = """Experience
Data Analyst
Tata Consultancy Services México | June 2022 – September 2022
• Cleansed, interpreted, and analysed data with Python and SQL Server to produce comprehensive and compelling visual reports using Power BI.
• Outperformed a pool of 60 fellow associates to join the “Business & Analytics” team in charge of delivering insightful data trends to Walgreen Co.
Legal Assistant
BLACKSHIIP Venture Capital | May 2022 – July 2022
• Proofread, drafted, and simplified Memorandums of Understanding (MoU), Terms &
Conditions, Data Processing Agreements, Privacy Policies, Letters of Intent (LOI),
Confidentiality Agreements, and Invitation Letters to International Conferences.
• Collaborated and strategized with CEO and Principal Attorney accurate outlines for the negotiation of International Share Purchase Agreements (SPA) between start-ups in
Latin America and BLACKSHIIP Venture Capital.
• Registered and familiarised with trademarks in The Mexican Institute of Industrial
Property (IMPI).
Data Analyst Jr.
AMATL GRÁFICOS | January 2020 – May 2022
• Developed and introduced A/B testing over the organisation to take data-backed
decisions that achieved an increase of 5 and 8 percentual points of Net Profit Margin for the fiscal years of 2020 and 2021, respectively.
    
• Persuaded and established the continuous use of NumPy, Pandas, Matplotlib, SQL Server, and Tableau/Power BI to collect, clean, manipulate and visualise data to carry out data-driven business decisions.
• Conceptualised and spearheaded new real-time data visualisations of Strategic KPIs aimed to measure and monitor operational and financial performance across the organisation.
Mathematics Instructor
ALOHA Mental Arithmetic | December 2019 – January 2020
• Taught mental arithmetic to groups of 10-15 students with an age range of 5 to 13 years.
• Applied auditory, visual and kinaesthetic methodologies for the integral development
of the class.
• Trained gifted children for national mental arithmetic competitions.
Special Needs Counsellor
Camp Merrywood (Ontario, Canada) | May 2019 - August 2019
• Led, guided, and monitored groups of 12-16 children, adolescents, and adults with
physical and mental disabilities, most of whom had muscular dystrophy, autism, or
cerebral palsy.
• Assisted with their personal hygiene 24 hours a day, helped in their feeding, and
facilitated their participation in all camp activities.
Special Needs Counsellor
YMCA Camp Independence (Chicago, USA) | June 2018 - August 2018
• Oversaw and coordinated groups of 5-10 children, adolescents, and adults with spina
bifida.
• Encouraged and coached campers in their personal goals of becoming more
independent despite their disability.
• Provided round-the-clock assistance with their personal cleanliness, aided with their
nutrition, and urged participation in all camp activities.

Volunteering
Coordinator of Volunteers
NAHUI OLLIN | November 2017 - May 2019
• Coordinated, guided, and gathered volunteers for the organisation in the state of Puebla.
• Directed and supervised the correct implementation of volunteering depending on the
physical and mental needs of the beneficiaries.
• The total number of volunteers within the organisation increased by 400% under my
lead.
• Due to the high number of volunteers, it was possible to offer our services to 3 nursing
homes simultaneously. This benefited approximately 150 elderlies per day of service.
Education & Qualifications
University of Bristol | LLB Law | (2022 - present)
• On an international exchange for my final year of studying Law. Member of the Honours Program at UDLAP | (2019 - present)
• Under the tutoring of Dr. Israel Cedillo Lazcano I have researched, revised, and written papers regarding FinTech, Financial Inclusion, Blockchain, Distributed Ledger Technologies, Cryptocurrencies, and Smart Contracts.
• Currently writing my dissertation about the potential real-world application of smart legal contracts in Mexico and the UK.
Universidad de las Américas Puebla (UDLAP) | LLB Law | (2019 – 2022)
• Undergraduate of law for three years with an accumulated average of 9.4/10.
The Internet-Based Test of English as a Foreign Language (TOEFL® iBT) | (2021 - 2023)
• Total score: 107 out of 120. Published Papers & Conferences
Smart Legal Contracts: From Theory to Reality
• Reyes, Juan Carlos, Smart Legal Contracts: From Theory to Reality (March 25, 2022). Available at SSRN: https://ssrn.com/abstract=4073055 or http://dx.doi.org/10.2139/ssrn.4073055
     
IDEAS Summer Program Intelligence, Data, Ethics, And Society | University of California, San Diego | July 31st – August 6th
• Invited by Professor David Danks to learn how to think critically and systematically about the ethical risks posed by AI and how to responsibly develop ML and data science systems that benefit the public.
Skills
• Written Communication Skills
• Verbal Communication Skills
• Teamwork
• Work Under Pressure
• Python
• SQL Server
• MySQL/PostgreSQL
• Tableau
• Power BI
• Bash/Command Line
• Git & GitHub
• Office 365
• Machine Learning
• Probabilities & Statistics
• Proofread
• Attention to Detail
• People Skills
• Judgement
• Leadership
PR"""

# %%
print(summarise_job(job_description))
# Out:
# SUMMARISE JOBS FUNCTION
#
# PROMPT TOKENS USED:1306
#  COMPLETION TOKENS USED:436
#
# COST FOR SUMMARISING: $0.006 USD
# ...

# %%
"""messages=[
            {'role': 'system', 'content': system_query},
            {'role': 'user', 'content': f"{delimiters}{job_to_summarise}{delimiters}"},
            {'role': 'assistant', 'content':assistant_query}
        ],"""
# Out:
# 'messages=[\n            {\'role\': \'system\', \'content\': system_query},\n            {\'role\': \'user\', \'content\': f"{delimiters}{job_to_summarise}{delimiters}"},\n            {\'role\': \'assistant\', \'content\':assistant_query}\n        ],'
