# %% [markdown]
# # Embedding Wikipedia articles for search
#
# This notebook shows how we prepared a dataset of Wikipedia articles for search, used in [Question_answering_using_embeddings.ipynb](Question_answering_using_embeddings.ipynb).
#
# Procedure:
#
# 0. Prerequisites: Import libraries, set API key (if needed)
# 1. Collect: We download a few hundred Wikipedia articles about the 2022 Olympics
# 2. Chunk: Documents are split into short, semi-self-contained sections to be embedded
# 3. Embed: Each section is embedded with the OpenAI API
# 4. Store: Embeddings are saved in a CSV file (for large datasets, use a vector database)

# %% [markdown]
# ## 0. Prerequisites
#
# ### Import libraries

# %%
# imports
import mwclient  # for downloading example Wikipedia articles
import mwparserfromhell  # for splitting Wikipedia articles into sections
import openai  # for generating embeddings
import pandas as pd  # for DataFrames to store article sections and embeddings
import re  # for cutting <ref> links out of Wikipedia articles
import tiktoken  # for counting tokens

# %% [markdown]
# Install any missing libraries with `pip install` in your terminal. E.g.,
#
# ```zsh
# pip install openai
# ```
#
# (You can also do this in a notebook cell with `!pip install openai`.)
#
# If you install any libraries, be sure to restart the notebook kernel.

# %% [markdown]
# ### Set API key (if needed)
#
# Note that the OpenAI library will try to read your API key from the `OPENAI_API_KEY` environment variable. If you haven't already, set this environment variable by following [these instructions](https://help.openai.com/en/articles/5112595-best-practices-for-api-key-safety).

# %% [markdown]
# ## 1. Collect documents
#
# In this example, we'll download a few hundred Wikipedia articles related to the 2022 Winter Olympics.

# %%
# get Wikipedia pages about the 2022 Winter Olympics

CATEGORY_TITLE = "Category:2022 Winter Olympics"
WIKI_SITE = "en.wikipedia.org"


def titles_from_category(
    category: mwclient.listing.Category, max_depth: int
) -> set[str]:
    """Return a set of page titles in a given Wiki category and its subcategories."""
    titles = set()
    for cm in category.members():
        if type(cm) == mwclient.page.Page:
            # ^type() used instead of isinstance() to catch match w/ no inheritance
            titles.add(cm.name)
        elif isinstance(cm, mwclient.listing.Category) and max_depth > 0:
            deeper_titles = titles_from_category(cm, max_depth=max_depth - 1)
            titles.update(deeper_titles)
    return titles


site = mwclient.Site(WIKI_SITE)
category_page = site.pages[CATEGORY_TITLE]
titles = titles_from_category(category_page, max_depth=1)
# ^note: max_depth=1 means we go one level deep in the category tree
print(f"Found {len(titles)} article titles in {CATEGORY_TITLE}.")
print(titles)
print(CATEGORY_TITLE)
# Out:
# Found 732 article titles in Category:2022 Winter Olympics.
# {'Maurice Manificat', 'Speed skating at the 2022 Winter Olympics – Qualification', 'Marek Hrivík', 'Anton Smolski', '2022 Winter Paralympics', 'Brett Gallant', 'Nikita Katsalapov', 'Christoffer Sundgren', '2022 Winter Olympics opening ceremony', 'Beijing National Stadium', 'Rock (ski course)', 'Jaclyn Narracott', 'Jutta Leerdam', 'Joonas Nättinen', 'Armenia at the 2022 Winter Olympics', 'Lviv bid for the 2022 Winter Olympics', 'Spain at the 2022 Winter Olympics', 'Marco Odermatt', 'Ireland at the 2022 Winter Olympics', 'Stefan Brennsteiner', 'Cayla Barnes', 'Omar Visintin', 'Kerttu Niskanen', 'Timur Bilyalov', 'Michela Moioli', 'Casey Dawson', 'Johannes Ludwig', 'Ebba Andersson (cross-country skier)', 'Elana Meyers Taylor', 'Nico Porteous', 'Brazil at the 2022 Winter Olympics', 'Nathan Chen', 'Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games', 'Julia Liikala', 'Malta at the 2022 Winter Olympics', 'Linus Straßer', 'Denmark at the 2022 Winter Olympics', 'Bulgaria at the 2022 Winter Olympics', 'Noora Tulus', 'Ice River (ski course)', 'Nika Križnar', 'Eric Frenzel', 'Mexico at the 2022 Winter Olympics', 'Timi Zajc', 'Ashton Bell', 'Irina Kazakevich', 'Mikhail Grigorenko', 'Christine de Bruin', 'Oleksandr Abramenko', 'Marijke Groenewoud', 'Joni Mäki', 'Miha Fontaine', 'Yuri Confortola', 'Henrik Harlaut', 'Bids for the 2022 Winter Olympics', 'Emily Clark (ice hockey)', '2020–21 figure skating season', "Meryeta O'Dine", 'Brianna Decker', 'Cene Prevc', 'Mark McMorris', 'Brittany Bowe', 'Jørgen Graabak', 'Anastasia Smirnova (freestyle skier)', '2022 Winter Olympics marketing', 'Peter Cehlárik', 'Claire Thompson (ice hockey)', 'Satsuki Fujisawa', 'Yumi Suzuki', 'Renata Fast', 'Alessandro Hämmerle', 'Wakaba Higuchi', 'Emery Lehman', 'Croatia at the 2022 Winter Olympics', 'Anna Berreiter', 'Angelina Golikova', 'Peter Zuzin', 'Saku Mäenalanen', 'India at the 2022 Winter Olympics', 'Alexander Samonov', 'Ice hockey at the 2022 Winter Olympics', 'Vetle Sjåstad Christiansen', 'Nordic combined at the 2022 Winter Olympics – Qualification', 'Almida de Val', 'Timor Leste at the 2022 Winter Olympics', 'Bobby Lammie', 'Jessie Diggins', 'Johannes Strolz', 'Ruslan Zakharov', 'Mathieu Faivre', 'Kyrgyzstan at the 2022 Winter Olympics', 'Jenni Hiirikoski', 'Ecuador at the 2022 Winter Olympics', 'Lee June-seo', '128th IOC Session', 'Eve Muirhead', 'Christopher Weber', 'Switzerland at the 2022 Winter Olympics', 'Su Yiming', 'Toni Eggert', 'Sanni Hakala', 'Beat Feuz', 'Shaoang Liu', 'Anton Slepyshev', 'List of 2022 Winter Paralympics medal winners', 'Marc Kennedy', 'Lebanon at the 2022 Winter Olympics', '2022 Winter Olympics medal table', 'Colby Stevenson', 'Chronological summary of the 2022 Winter Paralympics', 'Bruce Mouat', 'Johanna Heldin', 'Ski jumping at the 2022 Winter Olympics', 'Svetlana Mironova (biathlete)', 'South Korea at the 2022 Winter Olympics', 'Rebecca Johnston', 'Ilya Burov', 'Kelly Sildaru', 'Patrik Rybár', 'Kaori Sakamoto', 'Peru at the 2022 Winter Olympics', 'Sofia Mabergs', 'Sini Karjalainen', 'Great Britain at the 2022 Winter Olympics', 'Anna Hasselborg', 'Johannes Lochner', 'Konstantin Ivliev', 'Daniela Maier', 'Mona Brorsson', 'Haiti at the 2022 Winter Olympics', 'Finland at the 2022 Winter Olympics', '2021 Pre-Olympic Qualification Event', 'Mark Kondratiuk', 'Shijingshan District', 'Mislav Rosandić', 'Alexander Schmid', 'Cassie Sharpe', 'Joey Mantia', 'Chung Jae-won', 'Dani Cameranesi', 'Alex Cavallini', 'Rasmus Wranå', 'Nelli Laitinen', 'Jaelin Kauf', 'Gabriella Papadakis', 'Freestyle skiing at the 2022 Winter Olympics', 'Ikuma Horishima', 'Therese Johaug', 'Nick Goepper', 'Alexandria Loutitt', 'Fabian Wilkens Solheim', 'List of 2022 Winter Olympics broadcasters', 'Harri Säteri', 'Germany at the 2022 Winter Olympics', 'Yurika Yoshida', 'Martin Gernát', 'Tomáš Jurčo', 'Anastasia Mishina', 'Zhang Yuting', 'Tiril Eckhoff', 'Kim Min-seok (speed skater)', 'Lukas Greiderer', 'Meeri Räisänen', 'Ski jumping a ...
# Category:2022 Winter Olympics

# %% [markdown]
# ## 2. Chunk documents
#
# Now that we have our reference documents, we need to prepare them for search.
#
# Because GPT can only read a limited amount of text at once, we'll split each document into chunks short enough to be read.
#
# For this specific example on Wikipedia articles, we'll:
# - Discard less relevant-looking sections like External Links and Footnotes
# - Clean up the text by removing reference tags (e.g., <ref>), whitespace, and super short sections
# - Split each article into sections
# - Prepend titles and subtitles to each section's text, to help GPT understand the context
# - If a section is long (say, > 1,600 tokens), we'll recursively split it into smaller sections, trying to split along semantic boundaries like paragraphs

# %%
# define functions to split Wikipedia pages into sections

SECTIONS_TO_IGNORE = [
    "See also",
    "References",
    "External links",
    "Further reading",
    "Footnotes",
    "Bibliography",
    "Sources",
    "Citations",
    "Literature",
    "Footnotes",
    "Notes and references",
    "Photo gallery",
    "Works cited",
    "Photos",
    "Gallery",
    "Notes",
    "References and sources",
    "References and notes",
]


def all_subsections_from_section(
    section: mwparserfromhell.wikicode.Wikicode,
    parent_titles: list[str],
    sections_to_ignore: set[str],
) -> list[tuple[list[str], str]]:
    """
    From a Wikipedia section, return a flattened list of all nested subsections.
    Each subsection is a tuple, where:
        - the first element is a list of parent subtitles, starting with the page title
        - the second element is the text of the subsection (but not any children)
    """
    headings = [str(h) for h in section.filter_headings()]
    title = headings[0]
    if title.strip("=" + " ") in sections_to_ignore:
        # ^wiki headings are wrapped like "== Heading =="
        return []
    titles = parent_titles + [title]
    print(titles)
    full_text = str(section)
    section_text = full_text.split(title)[1]
    if len(headings) == 1:
        return [(titles, section_text)]
    else:
        first_subtitle = headings[1]
        section_text = section_text.split(first_subtitle)[0]
        results = [(titles, section_text)]
        for subsection in section.get_sections(levels=[len(titles) + 1]):
            results.extend(all_subsections_from_section(subsection, titles, sections_to_ignore))
        return results


def all_subsections_from_title(
    title: str,
    sections_to_ignore: set[str] = SECTIONS_TO_IGNORE,
    site_name: str = WIKI_SITE,
) -> list[tuple[list[str], str]]:
    """From a Wikipedia page title, return a flattened list of all nested subsections.
    Each subsection is a tuple, where:
        - the first element is a list of parent subtitles, starting with the page title
        - the second element is the text of the subsection (but not any children)
    """
    site = mwclient.Site(site_name)
    page = site.pages[title]
    text = page.text()
    parsed_text = mwparserfromhell.parse(text)
    headings = [str(h) for h in parsed_text.filter_headings()]
    if headings:
        summary_text = str(parsed_text).split(headings[0])[0]
    else:
        summary_text = str(parsed_text)
    results = [([title], summary_text)]
    for subsection in parsed_text.get_sections(levels=[2]):
        results.extend(all_subsections_from_section(subsection, [title], sections_to_ignore))
    return results

# %%
#for title in titles:
    #print(all_subsections_from_title(title))
# Out:
# ['Maurice Manificat', '==Career==']
# ['Maurice Manificat', '==Cross-country skiing results==']
# ['Maurice Manificat', '==Cross-country skiing results==', '===Olympic Games===']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Championships===']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===', '====Season standings====']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===', '====Individual podiums====']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===', '====Team podiums====']
# [(['Maurice Manificat'], "{{short description|French cross-country skier}}\n{{Infobox skier\n| name              = Maurice Manificat\n| image             = 20190301 FIS NWSC Seefeld Medal Ceremony 850 6085 Maurice Manificat.jpg\n| nationality       = {{FRA}}\n| birth_date        = {{birth date and age|1986|4|4|df=y}}\n| birth_place       = [[Sallanches]], [[Haute-Savoie]], France\n| height            = 1.85 m\n| club              = SC Agy St Sigismond\n| personalbest      = \n| seasons           = 17 – ([[2006–07 FIS Cross-Country World Cup|2007]]–present)\n| wins              = 10 <!-- 10 as of 24 March 2019 -->\n| totalpodiums      = 34 <!-- 34 as of 10 January 2021 -->\n| individual_starts = 249<!--249 as of 4 January 2023-->\n| teamwins          = 0  \n| teampodiums       = 2  <!--2 as of 15 Dec 2018-->\n| team_starts       = 16<!--16  as of 13 March 2022-->\n| wcoveralls        = 0 – (''5th in [[2009-10 FIS Cross-Country World Cup|2010]], [[2015-16 FIS Cross-Country World Cup|2016]]'')\n| wctitles          = 0\n| updated           = 28 March 2023\n| medaltemplates    = \n{{MedalSport|Men's [[Cross-country skiing (sport)|cross-country skiing]]}}\n{{Medal|Country|{{FRA}}}}\n{{Medal|Competition|International nordic ski competitions}}\n{{MedalCount|total=yes\n|[[Cross-country skiing at the Winter Olympics|Olympic Games]]|0|0|4\n|[[FIS Nordic World Ski Championships|World Championships]]|0|1|3\n}}\n{{MedalOlympic}}\n{{MedalBronze|[[2014 Winter Olympics|2014&nbsp;Sochi]]|[[Cross-country skiing at the 2014 Winter Olympics&nbsp;– Men's 4 × 10 kilometre relay|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay]]}}\n{{MedalBronze|[[2018 Winter Olympics|2018&nbsp;Pyeongchang]]|[[Cross-country skiing at the 2018 Winter Olympics – Men's 4 × 10 kilometre relay|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay]]}}\n{{MedalBronze|2018&nbsp;Pyeongchang|[[Cross-country skiing at the 2018 Winter Olympics – Men's team sprint|Team&nbsp;sprint]]}}\n{{MedalBronze|[[2022 Winter Olympics|2022&nbsp;Beijing]]|[[Cross-country skiing at the 2022 Winter Olympics – Men's 4 × 10 kilometre relay|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay]]}}\n{{Medal|Competition|[[FIS Nordic World Ski Championships|World Championships]]}}\n{{Medal|Silver|[[FIS Nordic World Ski Championships 2015|2015&nbsp;Falun]]|[[FIS Nordic World Ski Championships 2015 – Men's 15 kilometre freestyle|15&nbsp;km&nbsp;freestyle]]}}\n{{MedalBronze|2015&nbsp;Falun|[[FIS Nordic World Ski Championships 2015 – Men's 4 × 10 kilometre relay|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay]]}}\n{{MedalBronze|[[FIS Nordic World Ski Championships 2019|2019&nbsp;Seefeld]]|[[FIS Nordic World Ski Championships 2019 – Men's 4 × 10 kilometre relay|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay]]}}\n{{MedalBronze|[[FIS Nordic World Ski Championships 2021|2021&nbsp;Oberstdorf]]|[[FIS Nordic World Ski Championships 2021 – Men's 4 × 10 kilometre relay|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay]]}}\n{{Medal|Competition|[[FIS Nordic Junior World Ski Championships|U23 World Championships]]}}\n{{Medal|Gold|[[2009 Nordic Junior World Ski Championships|2009&nbsp;Praz&nbsp;de&nbsp;Lys-Sommand]]|15&nbsp;km&nbsp;freestyle}}\n{{Medal|Bronze|[[2008 Nordic Junior World Ski Championships|2008&nbsp;Mals]]|30&nbsp;km&nbsp;freestyle}}\n{{Medal|Competition|[[FIS Nordic Junior World Ski Championships|Junior World Championships]]}}\n{{Medal|Bronze|[[2005 Nordic Junior World Ski Championships|2005&nbsp;Rovaniemi]]|4&nbsp;×&nbsp;10&nbsp;km&nbsp;relay}}\n|caption=Manificat in 2019}}\n'''Maurice Manificat''' (born 4 April 1986) is a French [[Cross-country skiing (sport)|cross-country skier]] who has competed since 2004.\n\n"), (['Maurice Manificat', '==Career=='], '\nHe has achieved three World Cup victories, in [[Lahti]] (March 2010), in [[Canmore, Alberta|Canmore]] (December 2012), both in the 15&nbsp;km + 15&nbsp;km double pursuit event, and in [[Davos]] (December 2017), in 15&nbsp;km freestyle.\n\nManificat also finished 47th in the 15&nbsp;km + 15&nbsp;km double pursuit event at the [[FIS No ...
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Qualification times===']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Maximum entries by country per event===']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Maximum quotas per event===']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification timeline==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification summary==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 5000m and 10000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's Mass Start==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's Team pursuit==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 3000m and 5000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's Mass Start==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's Team pursuit==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 5000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 10000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's Team pursuit==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 3000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 5000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's Team pursuit==="]
# [(['Speed skating at the 2022 Winter Olympics – Qualification'], '{{short description|None}}\n\n{{Speed skating at the 2022 Winter Olympics}}\n\nThe following is about the qualification rules and the quota allocation for the [[Speed skating at the 2022 Winter Olympics|speed skating]] at the [[2022 Winter Olympics]].\n\n'), (['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules=='], "\nA total quota of 166 athletes were allowed to compete at the Games. Countries were assigned quotas based on their performance during the [[2021–22 ISU Speed Skating World Cup]] in the autumn of 2021. Each nation was permitted to enter a maximum of three athletes per gender for all events apart from the women's 5000m, men's 10000m and mass start events, for which they could enter a maximum of two athletes per event. Additionally, each nation is permitted to send at most 7 speed skating athletes per gender in total, or 8 when the nation is qualified for all events for the gender, or 9 when the nation is qualified with the maximum quota in every event for the gender.<ref>{{cite web|url=https://nocnsf.nl/media/3514/beijing-2022-qualification-system-speed-skating.pdf|title=Qualification Systems for XXIV Olympic Winter Games, Beijing 2022 Speed Skating|publisher=[[International Skating Union]]|accessdate=13 November 2021}}</ref>\n\n"), (['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Qualification times==='], '\nThe following qualification times were released on July 1, 2021, and were unchanged from 2018.<ref name=qt>{{cite web|url=https://www.isu.org/inside-isu/isu-communications/communications/25952-isu-communication-2405/file|title=Communication No. 2405 Qualifying competitions and qualifying times for Speed Skating events at the 2022 Olympic Winter Games|date=1 July 2021|website=www.isu.org/|publisher=[[International Skating Union]]|access-date=6 September 2021}}</ref> Skaters had the time period of July 1, 2021 – January 16, 2022 to achieve qualification times at valid [[International Skating Union]] (ISU) events.<ref name=qt/>\n\n{| class = "wikitable"\n! Event !! Men !! Women\n|-\n| 500 metres || align=center| 35.70 ||align=center| 39.50\n|-\n| 1000 metres || align=center| 1:10.50 ||align=center| 1:18.00\n|-\n| 1500 metres ||align=center| 1:48.00|| align=center| 1:59.50\n|-\n| 3000 metres ||{{n/a}}|| align=center| 4:12.00\n|-\n| 5000 metres ||align=center| 6:30.00  || align=center| 7:20.00 or 4:08.00 (3000 m)\n|-\n| 10,000 metres ||align=center|13:30.00 or 6:25.00 (5000 m) || {{n/a}}\n|-\n| Mass start ||align=center| 1:57.50 (1500 m)  || align=center| 2:10.00 (1500 m)\n|}\n\n'), (['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Maximum entries by country per event==='], '\n{| class = "wikitable"\n! Event !! Men !! Women\n|-\n| 500 metres || align=center| 3 ||align=center| 3\n|-\n| 1000 metres || align=center| 3 ||align=center| 3\n|-\n| 1500 metres ||align=center| 3|| align=center| 3\n|-\n| 3000 metres ||{{n/a}}|| align=center| 3\n|-\n| 5000 metres ||align=center| 3 || align=center|2\n|-\n| 10,000 metres ||align=center|2 || {{n/a}}\n|-\n| Mass start ||align=center|2  || align=center| 2\n|-\n| Team pursuit ||align=center| 1 team || align=center| 1 team\n|}\n\n'), (['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Maximum quotas per event==='], '\n;Men\n{| class = "wikitable"\n! Event !! By Ranking !! By time !! Total\n|-\n| 500 metres || align=center| 20 ||align=center| 10 || align=center| 30\n|-\n| 1000 metres || align=center| 20 ||align=center| 10 || align=center| 30\n|-\n| 1500 metres || align=center| 20 ||align=center| 10 || align=center| 30\n|-\n| 5000 metres || align=center| 14 ||align=center| 6 || align=center| 20\n|-\n| 10,000 metres || align=center| 8 ||align=center| 4 || align=center| 12\n|-\n| Mass start || align=center| 24 ||align=center {{n/a}} || align=center| 24\n|}\n\n;Wo ...
# ['Marek Hrivík', '==Playing career==']
# ['Marek Hrivík', '==Career statistics==']
# ['Marek Hrivík', '==Career statistics==', '===Regular season and playoffs===']
# ['Marek Hrivík', '==Career statistics==', '===International===']
# ['Marek Hrivík', '==Awards and honors==']
# [(['Marek Hrivík'], "{{short description|Slovak ice hockey player}}\n{{Infobox ice hockey player\n| name = Marek Hrivík\n| image = Marek Hrivik - New York Rangers.jpg\n| image_size = 230px\n| birth_date = {{birth date and age|mf=yes|1991|8|28}} \n| birth_place = [[Čadca]], [[Czechoslovakia]]\n| height_ft = 6\n| height_in = 2\n| weight_lb = 205\n| position = [[Winger (ice hockey)|Left wing]]/[[Centre (ice hockey)|Center]]\n| shoots = Left\n| team =[[Leksands IF]]\n| league = [[Swedish Hockey League|SHL]]\n| prospect_team = \n| prospect_league =\n| former_teams = [[New York Rangers]]<br />[[Calgary Flames]]<br />[[HC Vityaz]]<br />[[Torpedo Nizhny Novgorod]]\n| ntl_team = SVK\n| draft = Undrafted\n| career_start = 2008\n| career_end =\n}}\n\n'''Marek Hrivík''' (born August 28, 1991) is a Slovak professional [[ice hockey]] [[Forward (ice hockey)|forward]] currently playing for [[Leksands IF]] of the [[Swedish Hockey League]] (SHL).\n\n"), (['Marek Hrivík', '==Playing career=='], '\nHrivík won the [[President\'s Cup (QMJHL)|President\'s Cup]] in 2009–10 with the [[Moncton Wildcats]] of the [[Quebec Major Junior Hockey League]].<ref>[http://www.pluska.sk/sport/hokej/utocnika-mareka-hrivika-povolali-ny-rangers-bude-zbierat-skusenosti.html Pluska.sk - Šport - Hokej "Útočník Marek Hrivík nazbiera skúsenosti v NY Rangers"] 15 May 2012 (photo)</ref> On May 30, 2012, Hrivík signed his first NHL contract on a three-year entry-level contract with the [[New York Rangers]].<ref>{{cite web| url = http://rangers.nhl.com/club/news.htm?id=633251 | title = Hrivik gets first NHL deal with Blueshirts | publisher = [[New York Rangers]] | date = 2012-05-30 | accessdate = 2012-05-30}}</ref>\n\nHe made his NHL debut for the Rangers in a game against the [[Detroit Red Wings]] on February 21, 2016.<ref name=debut>{{cite web|title=Klein\'s overtime goal gives Rangers 1-0 win over Detroit|author=Canavan. T.|url=https://sports.yahoo.com/news/kleins-overtime-goal-gives-rangers-1-0-win-030209347--nhl.html|publisher=Yahoo Sports|date=February 21, 2016|accessdate=2016-02-22}}</ref>\n\nOn July 1, 2017, after five full seasons within the Rangers organization, Hrivík left as a free agent and was signed to a one-year, two-way contract with the [[Calgary Flames]].<ref>{{cite web| url =  https://www.nhl.com/flames/news/flames-sign-marek-hrivik/c-290261296 | title = Flames sign Marek Hrivik | publisher = [[Calgary Flames]] | date = 2017-07-01 | accessdate = 2017-07-01}}</ref> In the [[2017–18 NHL season|2017–18]] season, he was first assigned to AHL affiliate, the [[Stockton Heat]]. Having suffered through injury, Hrivík responded to produce 30 points in 32 games. He was later recalled to appear in 3 scoreless games with the Flames.\n\nOpting to leave the Flames in the off-season, Hrivík continued his career abroad, agreeing to a one-year deal with Russian club HC Vityaz of the KHL on July 1, 2018.<ref>{{cite web| url = http://www.hcvityaz.ru/news.php?full=9649 | title = Vityaz strengthen with Slovak Hrivik | publisher = [[HC Vityaz]] | date = 2018-07-01 | accessdate = 2018-07-01 | language = Russian}}</ref> In the [[2018–19 KHL season|2018–19]] season, Hrivík added eight goals and 15 points in 26 games with Vityaz before his season was cut short due to injury.\n\nAs a free agent, Hrivík left the KHL and agreed to a one-year deal with the newly promoted Swedish club, [[Leksands IF]] of the [[Swedish Hockey League]] (SHL), on 16 August 2019.<ref>{{cite web| url = https://www.leksandsif.se/artikel/9msrajzea-30ead/marek-hrivik-ansluter-till-leksands-if | title = Marek Hrivik joins Leksands | publisher = [[Leksands IF]] | date = 16 August 2019 | accessdate = 16 August 2019 | language = Swedish}}</ref>\n\nHrivík remained with Leksands for the [[2020–21 SHL season|2020–21]] season, increasing his scoring output to lead the team and the league in scoring with 37 assists and 51 points in just 44 regular season games. He was selected as the SHL\'s forward of the year and was a ...
# ['Anton Smolski', '==Biathlon results==']
# ['Anton Smolski', '==Biathlon results==', '===Olympic Games===']
# ['Anton Smolski', '==Biathlon results==', '===World Championships===']
# [(['Anton Smolski'], "{{short description|Belarusian biathlete}}\n{{Use dmy dates|date=February 2022}}\n{{Infobox sportsperson\n| name        = Anton Smolski\n| full_name   = \n| image       = \n| caption     = \n| nationality = Belarusian\n| sport       = Biathlon\n| event       = \n| club        = \n| collegeteam =\n| birth_date  = {{birth date and age|1996|12|16|df=yes}}\n| birth_place = Piasočnaje, [[Kapyl District]], Belarus\n| death_date  = \n| death_place = \n| height      = \n| weight      = \n| medaltemplates    = \n{{MedalSport|Men's [[biathlon]]}}\n{{MedalCountry | {{BLR}} }}\n{{MedalOlympic}}\n{{MedalSilver|[[2022 Winter Olympics|2022 Beijing]]|[[Biathlon at the 2022 Winter Olympics – Men's individual|20 km individual]]}}\n{{MedalCompetition|[[Biathlon Junior World Championships|Junior World Championships]]}}\n{{Medal|Bronze|[[Biathlon Junior World Championships 2017|2017 Osrblie]]|12.5 km Pursuit}}\n}}\n\n'''Anton Andrejevič Smolski''' ({{lang-be|Антон Андрэевіч Смольскі}}; born 16 December 1996) is a Belarusian [[biathlon|biathlete]]. He competed in the [[2018 Winter Olympics]].<ref>{{cite web |url=https://www.pyeongchang2018.com/en/game-time/results/OWG2018/en/biathlon/athlete-profile-n3022934-anton-smolski.htm |title=Athlete Profile: Anton SMOLSKI |website=PyeongChang2018.com |publisher=[[PyeongChang Organizing Committee for the 2018 Olympic & Paralympic Winter Games]] |url-status=dead|archiveurl=https://web.archive.org/web/20180420025843/https://www.pyeongchang2018.com/en/game-time/results/OWG2018/en/biathlon/athlete-profile-n3022934-anton-smolski.htm |archivedate=2018-04-20}}</ref>\n\n"), (['Anton Smolski', '==Biathlon results=='], '\nAll results are sourced from the [[International Biathlon Union]].\n\n'), (['Anton Smolski', '==Biathlon results==', '===Olympic Games==='], '\n\'\'1 medal (1 silver)\'\'\n{| class="wikitable" style="text-align: center;"\n|- "\n!Event\n!style="width:70px;"|Individual\n!style="width:70px;"|Sprint\n!style="width:70px;"|Pursuit\n!style="width:70px;"|{{nowrap|Mass start}}\n!style="width:70px;"|Relay\n!style="width:70px;"|{{nowrap|Mixed relay}}\n|-\n| align=left |{{flagicon|China}} [[Biathlon at the 2022 Winter Olympics|2022 Beijing]]\n| style="background:silver;"| \'\'\'Silver\'\'\'\n| 10th\n| 14th\n| 17th\n| 8th\n| 6th\n|-\n|}\n\n'), (['Anton Smolski', '==Biathlon results==', '===World Championships==='], '\n\'\'0 medals\'\'\n{| class="wikitable" style="text-align: center;"\n|- "\n!Event\n!style="width:70px;"|Individual\n!style="width:70px;"|Sprint\n!style="width:70px;"|Pursuit\n!style="width:70px;"|{{nowrap|Mass start}}\n!style="width:70px;"|Relay\n!style="width:70px;"|{{nowrap|Mixed relay}}\n!style="width:70px;"|{{nowrap|Single Mixed relay}}\n|-\n| align=left |{{flagicon|SLO}} [[Biathlon World Championships 2021|2021 Pokljuka]] \n| 29th\n| 33rd\n| 34th\n| —\n| 9th\n| 14th\n| —\n|}\n:\'\'*During Olympic seasons competitions are only held for those events not included in the Olympic program.\'\'\n:\'\'**The single mixed relay was added as an event in 2019.\'\'\n\n')]
# ['2022 Winter Paralympics', '== Host selection ==']
# ['2022 Winter Paralympics', '==Opening ceremony==']
# ['2022 Winter Paralympics', '==Closing ceremony==']
# ['2022 Winter Paralympics', '== Sports ==']
# ['2022 Winter Paralympics', '== Venues ==']
# ['2022 Winter Paralympics', '== Venues ==', '=== Beijing cluster ===']
# ['2022 Winter Paralympics', '== Venues ==', '=== [[Yanqing District]] cluster ===']
# ['2022 Winter Paralympics', '== Venues ==', '=== [[Zhangjiakou]] cluster ===']
# ['2022 Winter Paralympics', '== Participating National Paralympics Committees ==']
# ['2022 Winter Paralympics', '== Participating National Paralympics Committees ==', '===Number of athletes by National Paralympic Committee===']
# ['2022 Winter Paralympics', '==Calendar==']
# ['2022 Winter Paralympics', '==Medal summary==']
# ['2022 Winter Paralympics', '==Medal summary==', '=== Podium sweeps ===']
# ['2022 Winter Paralympics', '==Branding==']
# ['2022 Winter Paralympics', '==Branding==', '===Emblem===']
# ['2022 Winter Paralympics', '==Branding==', '===Mascot===']
# [(['2022 Winter Paralympics'], '{{Short description|Multi-parasport event in Beijing, China}}\n{{Use dmy dates|date=July 2020}}\n{{Infobox Olympic games|2022|Winter|Paralympics|\n| image       = 2022 Winter Paralympics logo (Full art).svg\n| image_size  = 201\n| host_city   = [[Beijing]], China\n| motto       = {{Unbulleted list|\'\'Together for a Shared Future\'\'|({{zh|s=一起向未来}})}}\n| nations     = 46<ref name="record_numbers_beijing_2022">{{Cite news |date=4 March 2022 |title=Record number of female Para athletes set for Beijing 2022 Paralympic Winter Games |work=Paralympic.org |url=https://www.paralympic.org/feature/record-number-female-para-athletes-set-beijing-2022-paralympic-winter-games |access-date=4 March 2022 |archive-date=4 March 2022 |archive-url=https://web.archive.org/web/20220304195652/https://www.paralympic.org/feature/record-number-female-para-athletes-set-beijing-2022-paralympic-winter-games |url-status=live }}</ref>\n| athletes    = 564<ref name="record_numbers_beijing_2022"/>\n| events      = 78 in 6 [[Paralympic sports|sports]]\n| opening     = 4 March\n| closing     = 13 March \n| opened_by   = [[President of the People\'s Republic of China|President]] [[Xi Jinping]]{{efn|Xi Jinping is current China\'s nominal head of state, serving as Chinese president. Xi is also the [[General Secretary of the Chinese Communist Party|general secretary of the Communist Party]], the most powerful position in China, serving as the [[Paramount leader]] of China.}}\n| cauldron    = [[Li Duan]]\n| stadium     = [[Beijing National Stadium]]\n| winter_prev = [[2018 Winter Paralympics|PyeongChang 2018]]\n| winter_next =  \'\'[[2026 Winter Paralympics|Milan-Cortina 2026]]\'\'\n| summer_prev = [[2020 Summer Paralympics|Tokyo 2020]]\n| summer_next = \'\'[[2024 Summer Paralympics|Paris 2024]]\'\'\n}}\n{{2022 Winter Paralympics}}\n[[File:2022 Winter Paralympics cauldron at Yanqing Winter Olympic Cultural Square (20220313142125).jpg|thumb|One of the four cauldrons used during the 2022 Winter Olympics and Paralympics]]\nThe \'\'\'2022 Winter Paralympics\'\'\' ({{zh|s=2022年冬季残疾人奥林匹克运动会|p=2022 Nián Dōngjì Cánjí Rén Àolínpǐkè Yùndònghuì}}), commonly known as \'\'\'Beijing 2022\'\'\' ({{zh|s=北京2022}}), was an international [[Winter sport|winter]] [[multi-sport event|multi-sport]] [[parasports]] event held in  [[Beijing]], China from 4 to 13 March 2022.<ref name="auto">{{Cite web|url=https://www.paralympic.org/feature/over-paralympians-hog-limelight-beijing|title=Over to Paralympians to hog limelight at Beijing|publisher=International Paralympic Committee|access-date=21 February 2022|archive-date=21 February 2022|archive-url=https://web.archive.org/web/20220221174014/https://www.paralympic.org/feature/over-paralympians-hog-limelight-beijing|url-status=live}}</ref> This was the 13th [[Winter Paralympic Games]], as administered by the [[International Paralympic Committee]] (IPC).\n\nBeijing was selected as the host city for the 2022 Winter Olympics and Paralympics in 2015 at the [[128th IOC Session]] in [[Kuala Lumpur]], Malaysia; taking into account its hosting of the [[2008 Summer Paralympics]], Beijing is the first city to have hosted both the Summer and Winter Olympics as well as the Summer and Winter Paralympics. This was the overall second Paralympics in China. It was the last of three consecutive Paralympics hosted in [[East Asia]].\n\nThese Games featured 564 athletes representing 46 [[National Paralympic Committee]]s (NPCs), competing in 78 medal events across six sports. Participation in the Games was impacted by the ongoing [[2022 Russian invasion of Ukraine|Russian invasion of Ukraine]]; the [[International Olympic Committee]] (IOC) condemned Russia for violating the [[Olympic Truce]], and called for both Russia and its [[Belarusian involvement in the 2022 Russian invasion of Ukraine|supporter]] Belarus to be excluded from international sporting events. While the IPC initially announced that the countries\' athletes would be allo ...
# ['Brett Gallant', '==Career==']
# ['Brett Gallant', '==Career==', '===Juniors===']
# ['Brett Gallant', '==Career==', "===Men's==="]
# ['Brett Gallant', '==Career==', '===2022 Winter Olympics===']
# ['Brett Gallant', '==Career==', '===Mixed doubles===']
# ['Brett Gallant', '==Personal life==']
# ['Brett Gallant', '==Awards==']
# [(['Brett Gallant'], '{{short description|Canadian curler}}\n{{for|the Canadian ice hockey player|Brett Gallant (ice hockey)}}\n{{Infobox curler\n| name = Brett Gallant\n| image = Brett Gallant Elite 10.jpg\n| caption = Gallant in 2018.\n| birth_name = Brett Philip Gallant\n| birth_date = {{birth date and age|1990|2|18}}\n| birth_place = [[Charlottetown]], [[Prince Edward Island]]\n| Curling club = [[The Glencoe Club]],{{citationneeded|date=November 2022}} <br /> [[Calgary|Calgary, AB]]\n| Skip = [[Brendan Bottcher]]\n| Third = [[Marc Kennedy]]\n| Second = \'\'\'Brett Gallant\'\'\' \n| Lead = [[Ben Hebert]]\n| Alternate = \n| Mixed doubles partner = [[Jocelyn Peterman]]\n| Member Association = {{PE}} (2006–2012) <br /> {{NL}} (2012–2022) <br /> {{AB}} (2022–present)\n| Brier appearances = 11 ({{Brier|2013}}, {{Brier|2014}}, {{Brier|2015}}, {{Brier|2016}}, {{Brier|2017}}, {{Brier|2018}}, {{Brier|2019}}, {{Brier|2020}}, {{Brier|2021}}, {{Brier|2022}}, {{Brier|2023}})\n| World Championship appearances = 3 ({{WMCC|2017}}, {{WMCC|2018}}, {{WMCC|2022}})\n| World Mixed Doubles Championship appearances = 2 ({{WMDCC|2019}}, {{WMDCC|2022}})\n| Olympic appearances = 1 ([[Curling at the 2022 Winter Olympics – Men\'s tournament|2022]])\n| Top CCA ranking = 1st ([[2016–17 curling season|2016–17]], [[2017–18 curling season|2017–18]], [[2021–22 curling season|2021–22]])\n| Grand Slam victories = 14: [[The National (curling)|The National]] (2015, 2021), [[Masters of Curling|Masters]] (2014, 2017), [[Canadian Open of Curling|Canadian Open]] (2014, 2017, 2023), [[Elite 10]] (2016, Sept. 2018), [[Players\' Championship|Players\']] (2016), [[GSOC Tour Challenge|Tour Challenge]] (2017), [[Champions Cup (curling)|Champions Cup]] (2018, 2022, 2023)\n| medaltemplates =\n{{MedalSport | Men\'s [[curling]]}}\n{{MedalCountry | {{CAN}} }}\n{{MedalCompetition | [[Winter Olympics]]}}\n{{MedalBronze| [[2022 Winter Olympics|2022 Beijing]]|[[Curling at the 2022 Winter Olympics – Men\'s tournament|Team]]}}\n{{MedalCompetition | [[World Curling Championships|World Championships]] }}\n{{MedalGold | [[2017 World Men\'s Curling Championship|2017 Edmonton]] | }}\n{{MedalSilver | [[2018 World Men\'s Curling Championship|2018 Las Vegas]] | }}\n{{MedalSilver | [[2022 World Men\'s Curling Championship|2022 Las Vegas]] | }}\n{{MedalCompetition | [[World Mixed Doubles Curling Championships|World Mixed Doubles Championship]] }}\n{{MedalSilver | [[2019 World Mixed Doubles Curling Championship|2019 Stavanger]] | }}\n{{MedalCompetition | [[World Junior Curling Championships|World Junior Championships]] }}\n{{MedalSilver| [[2009 World Junior Curling Championships|2009 Vancouver]] | }}\n{{MedalCompetition | [[Tim Hortons Brier]] }}\n{{MedalGold| [[2018 Tim Hortons Brier|2018 Regina]] | }}\n{{MedalCountry | {{NL}} }}\n{{MedalCompetition | [[Canadian Olympic Curling Trials]] }}\n{{MedalGold| [[2021 Canadian Olympic Curling Trials|2021 Saskatoon]] | }}\n{{MedalBronze| [[2017 Canadian Olympic Curling Trials|2017 Ottawa]] | }}\n{{MedalCompetition | [[Canadian Mixed Doubles Olympic Curling Trials|Canadian Mixed Doubles Olympic Trials]] }}\n{{MedalBronze | [[2018 Canadian Mixed Doubles Curling Olympic Trials|2018 Portage la Prairie]] | }}\n{{MedalCompetition | [[Tim Hortons Brier]] }}\n{{MedalGold | [[2017 Tim Hortons Brier|2017 St. John\'s]] | }}\n{{MedalGold | [[2020 Tim Hortons Brier|2020 Kingston]] | }}\n{{MedalSilver | [[2016 Tim Hortons Brier|2016 Ottawa]] | }}\n{{MedalCompetition | [[Canadian Mixed Doubles Curling Championship|Canadian Mixed Doubles Championship]]}}\n{{MedalGold | [[2016 Canadian Mixed Doubles Curling Trials|2016 Saskatoon]] |}}\n{{MedalGold | [[2019 Canadian Mixed Doubles Curling Championship|2019 Fredericton]] |}}\n{{MedalCountry | {{PE}} }}\n{{MedalCompetition | [[Canada Games]] }}\n{{MedalBronze | [[Curling at the 2007 Canada Games|2007 Whitehorse]] |  }}\n{{MedalCountry | {{flagicon|NL}} Wild Card }}\n{{MedalCompetition | [[Tim Hortons Brier]] }}\n{{MedalGo ...
# ['Nikita Katsalapov', '== Personal life ==']
# ['Nikita Katsalapov', '==Early career==']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===Junior career===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2010–11 season===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2011–12 season===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2012–13 season===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2013–14 season===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2014–15 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2015–16 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2016–17 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2017–18 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2018–19 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2019–20 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2020–21 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2021–22 season ===']
# ['Nikita Katsalapov', "==Support of Russia's invasion of Ukraine=="]
# ['Nikita Katsalapov', '==Programs==']
# ['Nikita Katsalapov', '==Programs==', '=== With Sinitsina ===']
# ['Nikita Katsalapov', '==Programs==', '=== With Ilinykh ===']
# ['Nikita Katsalapov', '== Records and achievements ==']
# ['Nikita Katsalapov', '==Competitive highlights==']
# ['Nikita Katsalapov', '==Competitive highlights==', '=== With Sinitsina ===']
# ['Nikita Katsalapov', '==Competitive highlights==', '=== With Ilinykh ===']
# ['Nikita Katsalapov', '==Detailed results==']
# ['Nikita Katsalapov', '==Detailed results==', '=== With Sinitsina===']
# ['Nikita Katsalapov', '==Detailed results==', '=== With Ilinykh ===']
# [(['Nikita Katsalapov'], "{{short description|Russian ice dancer}}\n{{family name hatnote|Gennadyevich|Katsalapov|lang=Eastern Slavic}}\n{{use dmy dates|date=April 2021}}\n{{Infobox figure skater\n|name= Nikita Katsalapov\n|image = Nikita Katsalapov in 2022 (cropped).jpg\n|imagesize = 230px\n|caption = Katsalapov at the [[Kremlin]] in 2022\n|native_name= Никита Геннадьевич Кацалапов\n|native_name_lang= ru\n|fullname= Nikita Gennadyevich Katsalapov\n|altname=\n|country= {{RUS}}\n|birth_date= {{birth date and age|1991|7|10|df=yes}}\n|birth_place= [[Moscow]], [[Russian Soviet Federative Socialist Republic|Russian SFSR]], [[Soviet Union]]\n|hometown=\n|residence= Moscow\n|height= {{height|m=1.80}}\n|partner= '''[[Victoria Sinitsina]]'''\n|formerpartner= [[Elena Ilinykh]] <br> Angelina Kabysheva\n|coach= [[Alexander Zhulin]] <br> Petr Durnev\n|formercoach= [[Marina Zoueva]] <br> [[Nikolai Morozov (figure skater)|Nikolai Morozov]] <br> Maria Voitsekhovskai <br> Denis Samokhin <br> [[Tatiana Tarasova]] <br> Oleg Volkov <br> [[Irina Lobacheva]]\n|choreographer= Sergei Petukhov\n|formerchoreographer= [[Nikolai Morozov (figure skater)|Nikolai Morozov]] <br> Liudmila Vlasova <br> [[Alexander Zhulin]]\n|skating club=  Olympic School Moskvich, Moscow\n|former skating club= Vorobievye Gory\n|currenttraininglocations= [[Moscow]]\n|formertraininglocations= Novogorsk, [[Ventspils]]\n|beganskating= 1995\n|retired= \n|worldranking = With Sinitsina <br /> '''1''' (''[[2020-21 ISU World Standings and Season's World Ranking|2020-21]]'') <br /> '''1''' (''[[2019-20 ISU World Standings and Season's World Ranking|2019-20]]'') <br /> '''2''' (''[[2018-19 ISU World Standings and Season's World Ranking|2018-19]]'') <br /> '''23''' (''[[2017–18 ISU World Standings and Season's World Ranking|2017–18]]'') <br /> '''18''' (''[[2016–17 ISU World Standings and Season's World Ranking|2016–17]]'') <br /> '''25''' (''[[2015–16 ISU World Standings and Season's World Ranking|2015–16]]'') <br /> '''70''' (''[[2014–15 ISU World Standings and Season's World Ranking|2014–15]]'') <br /> With Ilinykh <br /> '''7''' (''[[2013–14 ISU World Standings and Season's World Ranking|2013–14]]'') <br /> '''7''' (''[[2012–13 ISU World Standings and Season's World Ranking|2012–13]]'') <br /> '''10''' (''[[2011–12 ISU World Standings and Season's World Ranking|2011–12]]'') <br /> '''13''' (''[[2010–11 ISU World Standings and Season's World Ranking|2010–11]]'') <br /> '''31''' (''[[2009–10 ISU World Standings|2009–10]]'')\n|dance score= 221.17\n|dance date= [[2021 World Figure Skating Championships|2021 Worlds]]\n|SD score= 88.85\n|SD date= [[Figure skating at the 2022 Winter Olympics – Ice dance|2022 Olympics]]\n|FD score= 133.02\n|FD date= [[2021 World Figure Skating Championships|2021 Worlds]]\n|show-medals= yes\n| medaltemplates= \n{{MedalSport| [[Figure skating]]: [[Ice dance]]}}\n{{MedalCountry|{{flagIOC|ROC|2022 Winter}}<br>(with Sinitsina)}}\n{{MedalCompetition|[[Winter Olympic Games|Olympic Games]]}}\n[[File:Olympic rings.svg|center|80px]]\n{{MedalGold|[[2022 Winter Olympics|2022 Beijing]]|[[Figure skating at the 2022 Winter Olympics – Team event|Team]]}}\n{{MedalSilver|2022 Beijing|[[Figure skating at the 2022 Winter Olympics – Ice dance|Ice dancing]]}}\n{{MedalCountry| [[File:FSR Team flag (2021 WCh).svg|border|23px|FSR]] [[Figure Skating Federation of Russia|FSR]]}} <br> (with Sinitsina)\n{{MedalCompetition|[[World Figure Skating Championships|World Championships]]}}\n{{MedalGold|[[2021 World Figure Skating Championships|2021 Stockholm]]|Ice dancing}}\n{{MedalCountry | {{RUS}} }}<br />(with Sinitsina)\n{{MedalCompetition|[[World Figure Skating Championships|World Championships]]}}\n{{MedalSilver|[[2019 World Figure Skating Championships|2019 Saitama]]|Ice dancing}}\n{{MedalCompetition|[[European Figure Skating Championships|European Championships]]}}\n{{MedalGold|[[2020 European Figure Skating Championships|2020 Graz]]|Ice dancing}}\n{{MedalGold|[[2022 European Figure Skat ...
# ['Christoffer Sundgren', '== Curling career ==']
# ['Christoffer Sundgren', '== Curling career ==', '===Career beginnings===']
# ['Christoffer Sundgren', '== Curling career ==', "=== Men's (2011–present) ==="]
# ['Christoffer Sundgren', '== Curling career ==', '=== Career achievements ===']
# ['Christoffer Sundgren', '== Personal life ==']
# ['Christoffer Sundgren', '==Grand Slam record==']
# ['Christoffer Sundgren', '==Teams==']
# [(['Christoffer Sundgren'], "{{short description|Swedish curler}}\n{{Infobox curler\n| name = Christoffer Sundgren\n| image =  File:Christoffer_Sundgren.jpg\n| birth_date = {{birth date and age|1989|7|31|df=y}}\n| birth_place = [[Sveg]], [[Sweden]]\n| image_size = 200\n| Curling club = [[Karlstads Curlingklubb|Karlstads CK]], <br> [[Karlstad|Karlstad, SWE]]\n| Skip = [[Niklas Edin]]\n| Third = [[Oskar Eriksson]]\n| Second = [[Rasmus Wranå]]\n| Lead = '''Christoffer Sundgren'''\n| Alternate = [[Daniel Magnusson (curler)|Daniel Magnusson]]\n| Member Association = {{SWE}}\n| World Championship appearances = 9 ({{WMCC|2014}}, {{WMCC|2015}}, {{WMCC|2016}}, {{WMCC|2017}}, {{WMCC|2018}}, {{WMCC|2019}}, {{WMCC|2021}}, {{WMCC|2022}}, {{WMCC|2023}})\n| European Championship appearances = 8 ({{EuCC|2014}}, {{EuCC|2015}}, {{EuCC|2016}}, {{EuCC|2017}}, {{EuCC|2018}}, {{EuCC|2019}}, {{EuCC|2021}}, {{EuCC|2022}})\n| Olympic appearances = 2 ([[Curling at the 2018 Winter Olympics – Men's tournament|2018]], [[Curling at the 2022 Winter Olympics – Men's tournament|2022]])\n| Grand Slam victories = 4 ([[2016 WFG Masters|2016 Masters]], [[2016 GSOC Tour Challenge|2016 Tour Challenge]], [[2017 Players' Championship]], [[2022 Tour Challenge]])\n| medaltemplates=\n{{MedalSport | Men's [[Curling]] }}\n{{MedalCountry | {{SWE}} }}\n{{MedalOlympic}}\n{{MedalGold|[[2022 Winter Olympics|2022 Beijing]]|[[Curling at the 2022 Winter Olympics – Men's tournament|Team]] }}\n{{MedalSilver|[[2018 Winter Olympics|2018 Pyeongchang]]|[[Curling at the 2018 Winter Olympics – Men's tournament|Team]]}}\n{{MedalCompetition|[[World Curling Championships|World Championships]]}}\n{{MedalGold|[[2015 Ford World Men's Curling Championship|2015 Halifax]]|}}\n{{MedalGold|[[2018 World Men's Curling Championship|2018 Las Vegas]]|}}\n{{MedalGold|[[2019 World Men's Curling Championship|2019 Lethbridge]]|}}\n{{MedalGold|[[2021 World Men's Curling Championship|2021 Calgary]] | }}\n{{MedalGold | [[2022 World Men's Curling Championship|2022 Las Vegas]] | }}\n{{MedalSilver|[[2014 World Men's Curling Championship|2014 Beijing]]|}}\n{{MedalSilver|[[2017 World Men's Curling Championship|2017 Edmonton]]|}}\n{{MedalCompetition|[[European Curling Championships|European Championships]]}}\n{{MedalGold|[[2014 European Curling Championships|2014 Champéry]]|}}\n{{MedalGold|[[2015 European Curling Championships|2015 Esbjerg]]|}}\n{{MedalGold|[[2016 European Curling Championships|2016 Renfrewshire]]|}}\n{{MedalGold|[[2017 European Curling Championships|2017 St Gallen]]|}}\n{{MedalGold|[[2019 European Curling Championships|2019 Helsingborg]]|}}\n{{MedalSilver|[[2018 European Curling Championships|2018 Tallinn]]|}}\n{{MedalSilver|[[2021 European Curling Championships|2021 Lillehammer]]|}}\n{{MedalCompetition|[[World Junior Curling Championships|World Junior Championships]]}}\n{{MedalGold|[[2011 World Junior Curling Championships|2011 Perth]]|}}\n{{MedalCompetition|[[Universiade]]}}\n{{MedalGold|[[2013 Winter Universiade|2013 Trentino]]|}}\n}}\n\n'''Kjell Tommy Christoffer Sundgren''' (born 31 July 1989) is a Swedish [[Curling|curler]]. He currently plays [[lead (curling)|lead]] for the Swedish national team, skipped by [[Niklas Edin]]. The World Curling Federation's historical records rank Sundgren as one of the most successful curlers of all time, both in the medals that he has received and his lifetime performance in individual championships.<ref>{{Cite web|url=https://results.worldcurling.org/Record/IndividualMedals|title=Championships:Medals Won|website=World Curling Federation|access-date=2022-02-27}}</ref><ref>{{Cite web|url=https://results.worldcurling.org/Record/IndividualChampionships|title=Championships|website=World Curling Federation|access-date=2022-02-27}}</ref> He is one of only three curlers in history to have won both the Olympic Gold medal and five World Championship gold medals. In 2022, he surpassed the previous record holders for World Men's Curling Championship medals, winning his  ...
# ['2022 Winter Olympics opening ceremony', '==Ceremony key team==']
# ['2022 Winter Olympics opening ceremony', '==Theme and concept==']
# ['2022 Winter Olympics opening ceremony', '==Preparations==']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Rites of spring: Countdown performance===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Entry of the National flag===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Olympic Rings Reveal===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Parade of nations===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Opening of the Olympic Games===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Tribute to the People===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Olympic Flag Entry and Raising===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Oath taking===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Snowflakes performance===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Arrival and lighting of the Olympic flame===']
# ['2022 Winter Olympics opening ceremony', '==Anthems==']
# ['2022 Winter Olympics opening ceremony', '==Dignitaries in attendance==']
# ['2022 Winter Olympics opening ceremony', '==Dignitaries in attendance==', '===Host nation===']
# ['2022 Winter Olympics opening ceremony', '==Dignitaries in attendance==', '===International===']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', '===Diplomatic boycotts===']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', "===Taiwan's participation==="]
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', '===Ratings on NBC network===']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', '===Hanbok controversy===']
# [(['2022 Winter Olympics opening ceremony'], "{{Short description|Event in Beijing, China}}\n{{Use dmy dates|date=October 2021}}\n{{Infobox news event\n|title = 2022 Winter Olympics<br />opening ceremony\n|image_name = File:Putin attended the opening ceremony of 2022 Beijing Winter Olympics (2).jpg\n|image_size = \n|caption  = The cauldron of the games\n|date = {{Start date and age|2022|02|04|df=yes}}\n|time = 20:00 – 22:20 ([[UTC+08:00|UTC+8]], approximate)\n|theme = One World, One Family\n|venue = [[Beijing National Stadium]]\n|place = [[Beijing]], China\n|coordinates = {{coord|39|59|30|N|116|23|26|E|region:CN-11_type:landmark|display=inline,title}}\n|also known as =\n|filmed by  = [[China Central Television|CCTV]] and [[Olympic Broadcasting Services|OBS]]\n|participants =\n|awards  =\n|footage={{YouTube|NUs0iL5QOVI|2022 Winter Games Opening Ceremony in Olympic Channel}}|url =\n}}\n{{2022 Winter Olympics}}\nThe '''[[2022 Winter Olympics]] opening ceremony''' was held at [[Beijing National Stadium]], [[China]] on 4 February 2022. As mandated by the [[Olympic Charter]], the proceedings are expected to combine the formal and ceremonial opening of this international sporting event, including welcoming speeches, hoisting of the flags and the parade of athletes, with an artistic spectacle to showcase the host nation's winter culture and modern history.<ref>{{Cite web|date=2021-09-30|title=Olympic and Paralympic Winter Games Beijing 2022 – Updates on Spectators, Vaccination and COVID-19 Countermeasures|url=https://olympics.com/ioc/news/olympic-and-paralympic-winter-games-beijing-2022-updates-on-spectators-vaccination-and-covid-19-countermeasures|url-status=live|archive-url=https://web.archive.org/web/20211010144650/https://olympics.com/ioc/news/olympic-and-paralympic-winter-games-beijing-2022-updates-on-spectators-vaccination-and-covid-19-countermeasures|archive-date=10 October 2021|access-date=2021-10-10|website=International Olympic Committee}}</ref> The Games were officially opened by [[Xi Jinping]], [[general secretary of the Chinese Communist Party]] and [[president of the People's Republic of China]].<ref>{{Cite web|date=2021-11-23|title=How do the Olympic Games opening and closing ceremonies take place|url=https://olympics.com/ioc/faq/games-ceremonies-and-protocol/how-do-the-olympic-games-opening-and-closing-ceremonies-take-place|access-date=2021-12-08|website=International Olympic Committee|language=en|archive-date=19 November 2021|archive-url=https://web.archive.org/web/20211119013958/https://olympics.com/ioc/faq/games-ceremonies-and-protocol/how-do-the-olympic-games-opening-and-closing-ceremonies-take-place|url-status=live}}</ref>\n\nThe opening ceremony was directed by film director and producer [[Zhang Yimou]], who has previously directed the opening and closing ceremonies of the [[2008 Summer Olympics]], which was China's first time hosting the Olympics.<ref>{{cite news|title=Chinese director Zhang Yimou to oversee opening ceremony of 2022 Winter Olympics|url=https://www.thestandard.com.hk/breaking-news/section/3/185651/Chinese-director-Zhang-Yimou-to-oversee-opening-ceremony-of-2022-Winter-Olympics%C2%A0|access-date=19 January 2022|agency=Reuters|publisher=The Standard|date=8 January 2022|archive-date=19 January 2022|archive-url=https://web.archive.org/web/20220119224931/https://www.thestandard.com.hk/breaking-news/section/3/185651/Chinese-director-Zhang-Yimou-to-oversee-opening-ceremony-of-2022-Winter-Olympics%C2%A0|url-status=live }}</ref><ref>{{cite web|url=https://www.theguardian.com/sport/live/2022/feb/04/beijing-2022-winter-olympics-opening-ceremony-live|title=Beijing 2022: Winter Olympics opening ceremony – live!|date=4 February 2022|work=Guardian|access-date=4 February 2022|archive-date=4 February 2022|archive-url=https://web.archive.org/web/20220204111733/https://www.theguardian.com/sport/live/2022/feb/04/beijing-2022-winter-olympics-opening-ceremony-live|url-status=live}}</ref><ref>{{Cite web|url=https://www ...
# ['Beijing National Stadium', '==History==']
# ['Beijing National Stadium', '==History==', '===Bidding===']
# ['Beijing National Stadium', '==History==', '===Design===']
# ['Beijing National Stadium', '==History==', '===Construction===']
# ['Beijing National Stadium', '==History==', '===Completion===']
# ['Beijing National Stadium', '==Features and events==']
# ['Beijing National Stadium', '==Features and events==', '===Football===']
# ['Beijing National Stadium', '==Features and events==', '===Other sports events===']
# ['Beijing National Stadium', '==Features and events==', '===Concerts===']
# ['Beijing National Stadium', '==Features and events==', '===Pageants===']
# ['Beijing National Stadium', '==Features and events==', '===Post-Olympics legacy===']
# ['Beijing National Stadium', '==Features and events==', '===2022 Winter Olympics===']
# ...
# ['Linus Straßer', '==World cup results==']
# ['Linus Straßer', '==World cup results==', '===Season standings===']
# ['Linus Straßer', '==World cup results==', '===Race podiums===']
# ['Linus Straßer', '==World Championships results==']
# ['Linus Straßer', '==Olympic results==']
# [(['Linus Straßer'], "{{short description|German alpine skier}}\n{{Infobox alpine ski racer\n| name           = Linus Straßer\n| image          = 2018-01-15 Olympiaeinkleidung Deutschland 2018 by Sandro Halank–043.jpg\n| image_size     = 220px\n| caption        = Linus Straßer, 2018\n| disciplines    = [[Slalom skiing|Slalom]], [[Giant&nbsp;slalom]], [[FIS Alpine Ski World Cup#Parallel slalom|Parallel&nbsp;slalom]]\n| club           = [[TSV 1860 Munich|TSV 1860 München]]\n| birth_date     = {{Birth date and age|1992|11|6|df=y}}\n| birth_place    = [[Munich]], [[Germany]]<ref>[https://www.zoll.de/DE/Der-Zoll/Zollskiteam/Unser-Team/Alpin/Strasser-Linus/strasser-linus_node.html Profile] at German Customs Authority website</ref>\n| height         = 1.83 m\n| wcdebut        = 27 October [[2013–14 FIS Alpine Ski World Cup|2013]] (age 20)|\n| olympicteams   = 2 – ([[Germany at the 2018 Winter Olympics#Alpine skiing|2018]], [[Germany at the 2022 Winter Olympics#Alpine skiing|2022]])\n| olympicmedals  = 1\n| olympicgolds   = 0\n| worldsteams    = 5 – ([[FIS Alpine World Ski Championships 2015|2015]]–[[FIS Alpine World Ski Championships 2023|23]])\n| worldsmedals   = 1\n| worldsgolds    = 0\n| wcseasons      = 10 – ([[2013–14 FIS Alpine Ski World Cup|2014]]–[[2022–23 FIS Alpine Ski World Cup|2023]])\n| wcwins         = 3 – (2 [[FIS Alpine Ski World Cup#Slalom|SL]], 1 [[FIS Alpine Ski World Cup#Parallel slalom|PSL]])\n| wcpodiums      = 10 – (7 SL, 3 PSL)<!-- 10 through 9 Jan 2023 -->\n| wcoveralls     = 0 – ''(18th in [[2020–21 FIS Alpine Ski World Cup|2021]])''\n| wctitles       = 0 – ''(5th in [[2022 Alpine Skiing World Cup – Men's Slalom|SL]], [[2021–22 FIS Alpine Ski World Cup|2022]])''\n| show-medals    = yes\n| medaltemplates =\n{{Medal|Sport|Men's [[alpine skiing]]}}\n{{Medal|Country|{{GER}}}}\n{{Medal|Competition|[[Alpine skiing at the Winter Olympics|Olympic Games]]}}\n{{Medal|Silver|[[2022 Winter Olympics|2022 Beijing]]|[[Alpine skiing at the 2022 Winter Olympics – Mixed team|Team event]]}}\n{{MedalCompetition|[[FIS Alpine World Ski Championships|World Championships]]}}\n{{MedalBronze|[[FIS Alpine World Ski Championships 2021|2021 Cortina d’Ampezzo]]|[[FIS Alpine World Ski Championships 2021 – Nations team event|Team event]]}}\n}}\n'''Linus Straßer''' (born 6 November 1992) is a German [[FIS Alpine Ski World Cup|World Cup]] [[Alpine skiing|alpine ski racer]], a [[Slalom skiing|slalom]] specialist.<ref>[https://data.fis-ski.com/dynamic/athlete-biography.html?sector=AL&listid=&competitorid=137475 fis-ski.com] (Access: 8 January 2017).</ref> His first qualification for a World Cup second run came in a [[giant slalom]] at [[Beaver Creek Resort|Beaver Creek]] in December [[2013–14 FIS Alpine Ski World Cup|2014]], but he failed to finish. Straßer has competed in five [[FIS Alpine World Ski Championships|World Championships]]; in his first in [[FIS Alpine World Ski Championships 2015|2015]] at Beaver Creek, he was in tenth in the [[FIS Alpine World Ski Championships 2015 – Men's slalom|slalom]].<!-- and [[FIS Alpine World Ski Championships 2015 – Men's giant slalom|giant slalom]].<ref>{{cite web|url=http://data.fis-ski.com/pdf/2015/AL/0218/2015AL0218RLR2.pdf |title=Men's Giant Slalom Official Results|accessdate=14 February 2015}}</ref>--> His first World Cup podium was a victory in a [[FIS Alpine Ski World Cup#Parallel slalom|parallel slalom]] race in [[Stockholm]] in January [[2016–17 FIS Alpine Ski World Cup|2017]].\n\n"), (['Linus Straßer', '==World cup results=='], '\n'), (['Linus Straßer', '==World cup results==', '===Season standings==='], '\n{| class=wikitable style="text-align:center"\n! Season\n! Age\n! Overall\n! Slalom\n! Giant<br>slalom\n! Super-G\n! Downhill\n! Combined\n! Parallel\n|-\n| [[2014–15 FIS Alpine Ski World Cup|2015]] ||\'\'22\'\'|| 64 || 21 || — || — || — || — || rowspan=5 {{n/a}}\n|-\n| [[2015–16 FIS Alpine Ski World Cup|2016]] ||\'\'23\'\'|| [[2016 Alpine Skiing World Cup – Men\'s Overall|114]] || [[2016 A ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 for title in titles:
# ----> 2     print(all_subsections_from_title(title))
#
# Cell In[3], line 66, in all_subsections_from_title(title, sections_to_ignore, site_name)
#      56 def all_subsections_from_title(
#      57     title: str,
#      58     sections_to_ignore: set[str] = SECTIONS_TO_IGNORE,
#      59     site_name: str = WIKI_SITE,
#      60 ) -> list[tuple[list[str], str]]:
#      61     """From a Wikipedia page title, return a flattened list of all nested subsections.
#      62     Each subsection is a tuple, where:
#      63         - the first element is a list of parent subtitles, starting with the page title
#      64         - the second element is the text of the subsection (but not any children)
#      65     """
# ---> 66     site = mwclient.Site(site_name)
#      67     page = site.pages[title]
#      68     text = page.text()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:130, in Site.__init__(self, host, path, ext, pool, retry_timeout, max_retries, wait_callback, clients_useragent, max_lag, compress, force_login, do_init, httpauth, reqs, consumer_token, consumer_secret, access_token, access_secret, client_certificate, custom_headers, scheme)
#     128 if do_init:
#     129     try:
# --> 130         self.site_init()
#     131     except errors.APIError as e:
#     132         if e.args[0] == 'mwoauth-invalid-authorization':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:150, in Site.site_init(self)
#     147     self.tokens = {}
#     148     return
# --> 150 meta = self.get('query', meta='siteinfo|userinfo',
#     151                 siprop='general|namespaces', uiprop='groups|rights',
#     152                 retry_on_error=False)
#     154 # Extract site info
#     155 self.site = meta['query']['general']
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:234, in Site.get(self, action, *args, **kwargs)
#     225 def get(self, action, *args, **kwargs):
#     226     """Perform a generic API call using GET.
#     227
#     228     This is just a shorthand for calling api() with http_method='GET'.
#    (...)
#     232         The raw response from the API call, as a dictionary.
#     233     """
# --> 234     return self.api(action, 'GET', *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:285, in Site.api(self, action, http_method, *args, **kwargs)
#     282 sleeper = self.sleepers.make()
#     284 while True:
# --> 285     info = self.raw_api(action, http_method, **kwargs)
#     286     if not info:
#     287         info = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:437, in Site.raw_api(self, action, http_method, *args, **kwargs)
#     435 kwargs['format'] = 'json'
#     436 data = self._query_string(*args, **kwargs)
# --> 437 res = self.raw_call('api', data, retry_on_error=retry_on_error,
#     438                     http_method=http_method)
#     440 try:
#     441     return json.loads(res, object_pairs_hook=OrderedDict)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:399, in Site.raw_call(self, script, data, files, retry_on_error, http_method)
#     396 else:
#     397     args['data'] = data
# --> 399 stream = self.connection.request(http_method, url, **args)
#     401 if stream.headers.get('x-database-lag'):
#     402     wait_time = int(stream.headers.get('retry-after'))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
# split pages into sections
# may take ~1 minute per 100 articles
wikipedia_sections = []
for title in titles:
    wikipedia_sections.extend(all_subsections_from_title(title))
print(f"Found {len(wikipedia_sections)} sections in {len(titles)} pages.")
# Out:
# ['Maurice Manificat', '==Career==']
# ['Maurice Manificat', '==Cross-country skiing results==']
# ['Maurice Manificat', '==Cross-country skiing results==', '===Olympic Games===']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Championships===']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===', '====Season standings====']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===', '====Individual podiums====']
# ['Maurice Manificat', '==Cross-country skiing results==', '===World Cup===', '====Team podiums====']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Qualification times===']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Maximum entries by country per event===']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification rules==', '===Maximum quotas per event===']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification timeline==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Qualification summary==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's 5000m and 10000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's Mass Start==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Men's Team pursuit==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's 3000m and 5000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's Mass Start==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Points Ranking==', "===Women's Team pursuit==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==']
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 5000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's 10000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Men's Team pursuit==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 1000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 1500m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 3000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's 5000m==="]
# ['Speed skating at the 2022 Winter Olympics – Qualification', '==Time Ranking==', "===Women's Team pursuit==="]
# ['Marek Hrivík', '==Playing career==']
# ['Marek Hrivík', '==Career statistics==']
# ['Marek Hrivík', '==Career statistics==', '===Regular season and playoffs===']
# ['Marek Hrivík', '==Career statistics==', '===International===']
# ['Marek Hrivík', '==Awards and honors==']
# ['Anton Smolski', '==Biathlon results==']
# ['Anton Smolski', '==Biathlon results==', '===Olympic Games===']
# ['Anton Smolski', '==Biathlon results==', '===World Championships===']
# ['2022 Winter Paralympics', '== Host selection ==']
# ['2022 Winter Paralympics', '==Opening ceremony==']
# ['2022 Winter Paralympics', '==Closing ceremony==']
# ['2022 Winter Paralympics', '== Sports ==']
# ['2022 Winter Paralympics', '== Venues ==']
# ['2022 Winter Paralympics', '== Venues ==', '=== Beijing cluster ===']
# ['2022 Winter Paralympics', '== Venues ==', '=== [[Yanqing District]] cluster ===']
# ['2022 Winter Paralympics', '== Venues ==', '=== [[Zhangjiakou]] cluster ===']
# ['2022 Winter Paralympics', '== Participating National Paralympics Committees ==']
# ['2022 Winter Paralympics', '== Participating National Paralympics Committees ==', '===Number of athletes by National Paralympic Committee===']
# ['2022 Winter Paralympics', '==Calendar==']
# ['2022 Winter Paralympics', '==Medal summary==']
# ['2022 Winter Paralympics', '==Medal summary==', '=== Podium sweeps ===']
# ['2022 Winter Paralympics', '==Branding==']
# ['2022 Winter Paralympics', '==Branding==', '===Emblem===']
# ['2022 Winter Paralympics', '==Branding==', '===Mascot===']
# ['Brett Gallant', '==Career==']
# ['Brett Gallant', '==Career==', '===Juniors===']
# ['Brett Gallant', '==Career==', "===Men's==="]
# ['Brett Gallant', '==Career==', '===2022 Winter Olympics===']
# ['Brett Gallant', '==Career==', '===Mixed doubles===']
# ['Brett Gallant', '==Personal life==']
# ['Brett Gallant', '==Awards==']
# ['Nikita Katsalapov', '== Personal life ==']
# ['Nikita Katsalapov', '==Early career==']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===Junior career===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2010–11 season===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2011–12 season===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2012–13 season===']
# ['Nikita Katsalapov', '==Partnership with Ilinykh==', '===2013–14 season===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2014–15 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2015–16 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2016–17 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2017–18 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2018–19 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2019–20 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2020–21 season ===']
# ['Nikita Katsalapov', '==Partnership with Sinitsina==', '=== 2021–22 season ===']
# ['Nikita Katsalapov', "==Support of Russia's invasion of Ukraine=="]
# ['Nikita Katsalapov', '==Programs==']
# ['Nikita Katsalapov', '==Programs==', '=== With Sinitsina ===']
# ['Nikita Katsalapov', '==Programs==', '=== With Ilinykh ===']
# ['Nikita Katsalapov', '== Records and achievements ==']
# ['Nikita Katsalapov', '==Competitive highlights==']
# ['Nikita Katsalapov', '==Competitive highlights==', '=== With Sinitsina ===']
# ['Nikita Katsalapov', '==Competitive highlights==', '=== With Ilinykh ===']
# ['Nikita Katsalapov', '==Detailed results==']
# ['Nikita Katsalapov', '==Detailed results==', '=== With Sinitsina===']
# ['Nikita Katsalapov', '==Detailed results==', '=== With Ilinykh ===']
# ['Christoffer Sundgren', '== Curling career ==']
# ['Christoffer Sundgren', '== Curling career ==', '===Career beginnings===']
# ['Christoffer Sundgren', '== Curling career ==', "=== Men's (2011–present) ==="]
# ['Christoffer Sundgren', '== Curling career ==', '=== Career achievements ===']
# ['Christoffer Sundgren', '== Personal life ==']
# ['Christoffer Sundgren', '==Grand Slam record==']
# ['Christoffer Sundgren', '==Teams==']
# ['2022 Winter Olympics opening ceremony', '==Ceremony key team==']
# ['2022 Winter Olympics opening ceremony', '==Theme and concept==']
# ['2022 Winter Olympics opening ceremony', '==Preparations==']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Rites of spring: Countdown performance===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Entry of the National flag===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Olympic Rings Reveal===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Parade of nations===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Opening of the Olympic Games===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Tribute to the People===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Olympic Flag Entry and Raising===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Oath taking===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Snowflakes performance===']
# ['2022 Winter Olympics opening ceremony', '==Proceedings==', '===Arrival and lighting of the Olympic flame===']
# ['2022 Winter Olympics opening ceremony', '==Anthems==']
# ['2022 Winter Olympics opening ceremony', '==Dignitaries in attendance==']
# ['2022 Winter Olympics opening ceremony', '==Dignitaries in attendance==', '===Host nation===']
# ['2022 Winter Olympics opening ceremony', '==Dignitaries in attendance==', '===International===']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', '===Diplomatic boycotts===']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', "===Taiwan's participation==="]
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', '===Ratings on NBC network===']
# ['2022 Winter Olympics opening ceremony', '==Controversy and concerns==', '===Hanbok controversy===']
# ['Beijing National Stadium', '==History==']
# ['Beijing National Stadium', '==History==', '===Bidding===']
# ['Beijing National Stadium', '==History==', '===Design===']
# ['Beijing National Stadium', '==History==', '===Construction===']
# ['Beijing National Stadium', '==History==', '===Completion===']
# ['Beijing National Stadium', '==Features and events==']
# ['Beijing National Stadium', '==Features and events==', '===Football===']
# ['Beijing National Stadium', '==Features and events==', '===Other sports events===']
# ['Beijing National Stadium', '==Features and events==', '===Concerts===']
# ['Beijing National Stadium', '==Features and events==', '===Pageants===']
# ['Beijing National Stadium', '==Features and events==', '===Post-Olympics legacy===']
# ['Beijing National Stadium', '==Features and events==', '===2022 Winter Olympics===']
# ['Rock (ski course)', '== History ==']
# ['Rock (ski course)', '== Olympics ==']
# ['Rock (ski course)', '== Olympics ==', '=== Men ===']
# ['Rock (ski course)', '== Olympics ==', '=== Women ===']
# ['Rock (ski course)', '== World Cup ==']
# ['Rock (ski course)', '== World Cup ==', '=== Men ===']
# ['Rock (ski course)', '== Profile ==']
# ['Rock (ski course)', '== Profile ==', '=== Course sections ===']
# ['Jaclyn Narracott', '==Notable results==']
# ['Jutta Leerdam', '==Career==']
# ['Jutta Leerdam', '==Personal life==']
# ['Jutta Leerdam', '==Records==']
# ['Jutta Leerdam', '==Records==', '===Personal records===']
# ['Jutta Leerdam', '==Records==', '===World record===']
# ['Jutta Leerdam', '==Tournament overview==']
# ['Jutta Leerdam', '==World Cup overview==']
# ['Joonas Nättinen', '==Playing career==']
# ['Joonas Nättinen', '==Career statistics==']
# ['Joonas Nättinen', '==Career statistics==', '===Regular season and playoffs===']
# ['Joonas Nättinen', '==Career statistics==', '===International===']
# ['Armenia at the 2022 Winter Olympics', '==Competitors==']
# ['Armenia at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Armenia at the 2022 Winter Olympics', '==Cross-country skiing==']
# ['Armenia at the 2022 Winter Olympics', '==Figure skating==']
# ['Lviv bid for the 2022 Winter Olympics', '==History==']
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==']
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==', '===City zone===']
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==', '===Mountain zone===']
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==', '===Mountain zone===', '====Venue cluster Tysovets-Panasivka====']
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==', '===Mountain zone===', '====Venue cluster Borzhava====']
# ['Spain at the 2022 Winter Olympics', '==Medalists==']
# ['Spain at the 2022 Winter Olympics', '==Competitors==']
# ['Spain at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Spain at the 2022 Winter Olympics', '==Cross-country skiing==']
# ['Spain at the 2022 Winter Olympics', '==Figure skating==']
# ['Spain at the 2022 Winter Olympics', '==Freestyle skiing==']
# ['Spain at the 2022 Winter Olympics', '==Skeleton==']
# ['Spain at the 2022 Winter Olympics', '==Snowboarding==']
# ['Marco Odermatt', '==Career==']
# ['Marco Odermatt', '==World Cup results==']
# ['Marco Odermatt', '==World Cup results==', '===Season titles===']
# ['Marco Odermatt', '==World Cup results==', '===Season standings===']
# ['Marco Odermatt', '==World Cup results==', '===Race victories===']
# ['Marco Odermatt', '==World Championship results==']
# ['Marco Odermatt', '== Olympic Results ==']
# ['Marco Odermatt', '== Junior World Championship results ==']
# ['Ireland at the 2022 Winter Olympics', '==Competitors==']
# ['Ireland at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Ireland at the 2022 Winter Olympics', '==Cross-country skiing==']
# ['Ireland at the 2022 Winter Olympics', '==Freestyle skiing==']
# ['Ireland at the 2022 Winter Olympics', '==Luge==']
# ['Ireland at the 2022 Winter Olympics', '==Snowboarding==']
# ['Stefan Brennsteiner', '==Career==']
# ['Stefan Brennsteiner', '==World Cup results==']
# ['Stefan Brennsteiner', '==World Cup results==', '===Season standings===']
# ['Stefan Brennsteiner', '==World Cup results==', '===Race podiums===']
# ['Stefan Brennsteiner', '==World Championship results==']
# ['Stefan Brennsteiner', '== Olympic results<!--[[File:Olympic rings.svg|50px]]-->==']
# ['Cayla Barnes', '== Playing career ==']
# ['Cayla Barnes', '== Playing career ==', '=== International play ===']
# ['Cayla Barnes', '== Career statistics ==']
# ['Cayla Barnes', '== Career statistics ==', '===Awards and honors===']
# ['Omar Visintin', '==World Cup Podiums==']
# ['Kerttu Niskanen', '==Career==']
# ['Kerttu Niskanen', '==Cross-country skiing results==']
# ['Kerttu Niskanen', '==Cross-country skiing results==', '===Olympic Games===']
# ['Kerttu Niskanen', '==Cross-country skiing results==', '===World Championships===']
# ['Kerttu Niskanen', '==Cross-country skiing results==', '===World Cup===']
# ['Kerttu Niskanen', '==Cross-country skiing results==', '===World Cup===', '====Season standings====']
# ['Kerttu Niskanen', '==Cross-country skiing results==', '===World Cup===', '====Individual podiums====']
# ['Kerttu Niskanen', '==Cross-country skiing results==', '===World Cup===', '====Team podiums====']
# ['Timur Bilyalov', '==International play==']
# ['Michela Moioli', '==Biography==']
# ['Michela Moioli', '==World Cup==']
# ['Michela Moioli', '==World Cup==', '===Overall===']
# ['Michela Moioli', '==World Cup==', '===Podium===']
# ['Casey Dawson', '==Career==']
# ['Johannes Ludwig', '==Career==']
# ['Johannes Ludwig', '==Luge results==']
# ['Johannes Ludwig', '==Luge results==', '===World Cup===']
# ['Ebba Andersson (cross-country skier)', '==Running ==']
# ['Ebba Andersson (cross-country skier)', '==Roller skiing==']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===Olympic Games===']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===World Championships===']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===World Cup===']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===World Cup===', '====Season titles====']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===World Cup===', '====Season standings====']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===World Cup===', '====Individual podiums====']
# ['Ebba Andersson (cross-country skier)', '==Cross-country skiing results==', '===World Cup===', '====Team podiums====']
# ['Elana Meyers Taylor', '==Career==']
# ['Elana Meyers Taylor', '==Personal life==']
# ['Elana Meyers Taylor', '== Activism and overcoming adversity ==']
# ['Nico Porteous', '==Early life and family==']
# ['Nico Porteous', '==Career==']
# ['Brazil at the 2022 Winter Olympics', '==Competitors==']
# ['Brazil at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Brazil at the 2022 Winter Olympics', '==Bobsleigh==']
# ['Brazil at the 2022 Winter Olympics', '==Cross-country skiing==']
# ['Brazil at the 2022 Winter Olympics', '==Freestyle skiing==']
# ['Brazil at the 2022 Winter Olympics', '==Skeleton==']
# ['Nathan Chen', '==Early life and family==']
# ['Nathan Chen', '==Competitive skating career==']
# ['Nathan Chen', '==Competitive skating career==', '=== Early career ===']
# ['Nathan Chen', '==Competitive skating career==', '===Junior career ===']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===', '====2016–2017 season: Senior international debut, Four Continents title & first senior national title====']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===', '====2017–2018 season: Pyeongchang Olympics & first World title====']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===', '====2018–2019 season: Second consecutive World title====']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===', '====2019–2020 season: Third consecutive Grand Prix Final title====']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===', '====2020–2021 season: Third consecutive World title====']
# ['Nathan Chen', '==Competitive skating career==', '===Senior career ===', '====2021–2022 season: Olympic gold medal====']
# ['Nathan Chen', '==Show skating career==']
# ['Nathan Chen', '==Show skating career==', '=== Coaching ===']
# ['Nathan Chen', '==Skating technique and style==']
# ['Nathan Chen', '==Public life and popular culture==']
# ['Nathan Chen', '==Public life and popular culture==', '===Endorsements===']
# ['Nathan Chen', '==Public life and popular culture==', '===Ambassadorships===']
# ['Nathan Chen', '==Public life and popular culture==', '===Books and magazines===']
# ['Nathan Chen', '==Public life and popular culture==', '===Television===']
# ['Nathan Chen', '==Public life and popular culture==', '=== Philanthropic work and supported causes ===']
# ['Nathan Chen', '== Honors and awards ==']
# ['Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games', '==Organisation structure==']
# ['Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games', '==Organisation structure==', '===Leadership===']
# ['Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games', '==Organisation structure==', '===Departments===']
# ['Julia Liikala', '== Playing career ==']
# ['Julia Liikala', '== International play ==']
# ['Julia Liikala', '== International play ==', '=== Statistics ===']
# ['Malta at the 2022 Winter Olympics', '==Competitors==']
# ['Malta at the 2022 Winter Olympics', '==Snowboarding==']
# ['Malta at the 2022 Winter Olympics', '==Non-competing sports==']
# ['Malta at the 2022 Winter Olympics', '==Non-competing sports==', '===Alpine skiing===']
# ['Linus Straßer', '==World cup results==']
# ['Linus Straßer', '==World cup results==', '===Season standings===']
# ['Linus Straßer', '==World cup results==', '===Race podiums===']
# ['Linus Straßer', '==World Championships results==']
# ['Linus Straßer', '==Olympic results==']
# ['Denmark at the 2022 Winter Olympics', '==Competitors==']
# ['Denmark at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Denmark at the 2022 Winter Olympics', '==Biathlon==']
# ['Denmark at the 2022 Winter Olympics', '==Curling==']
# ['Denmark at the 2022 Winter Olympics', '==Curling==', "===Men's tournament==="]
# ['Denmark at the 2022 Winter Olympics', '==Curling==', "===Women's tournament==="]
# ['Denmark at the 2022 Winter Olympics', '==Ice hockey==']
# ['Denmark at the 2022 Winter Olympics', '==Ice hockey==', "===Men's tournament==="]
# ['Denmark at the 2022 Winter Olympics', '==Ice hockey==', "===Women's tournament==="]
# ['Denmark at the 2022 Winter Olympics', '== Speed skating ==']
# ['Denmark at the 2022 Winter Olympics', '==Non-competing sports==']
# ['Denmark at the 2022 Winter Olympics', '==Non-competing sports==', '===Cross-country skiing===']
# ['Bulgaria at the 2022 Winter Olympics', '==Competitors==']
# ['Bulgaria at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Bulgaria at the 2022 Winter Olympics', '==Biathlon==']
# ['Bulgaria at the 2022 Winter Olympics', '==Figure skating==']
# ['Bulgaria at the 2022 Winter Olympics', '==Luge==']
# ['Bulgaria at the 2022 Winter Olympics', '==Ski jumping==']
# ['Bulgaria at the 2022 Winter Olympics', '==Snowboarding==']
# ['Bulgaria at the 2022 Winter Olympics', '==Non-competing sports==']
# ['Bulgaria at the 2022 Winter Olympics', '==Non-competing sports==', '===Cross-country skiing===']
# ['Noora Tulus', '== Playing career ==']
# ['Noora Tulus', '== International career ==']
# ['Ice River (ski course)', '== History ==']
# ['Ice River (ski course)', '== Olympics ==']
# ['Ice River (ski course)', '== Olympics ==', '=== Women ===']
# ['Ice River (ski course)', '== Olympics ==', '=== Men ===']
# ['Nika Križnar', '==Career==']
# ['Nika Križnar', '==Major tournament results==']
# ['Nika Križnar', '==Major tournament results==', '===Winter Olympics===']
# ['Nika Križnar', '==Major tournament results==', '===FIS Nordic World Ski Championships===']
# ['Nika Križnar', '==World Cup==']
# ['Nika Križnar', '==World Cup==', '===Standings===']
# ['Nika Križnar', '==World Cup==', '===Individual wins===']
# ['Nika Križnar', '==World Cup==', '===Individual starts===']
# ['Eric Frenzel', '==Career==']
# ['Eric Frenzel', '==Record==']
# ['Eric Frenzel', '==Record==', '===Olympic Games===']
# ['Eric Frenzel', '==Record==', '===World Championship===']
# ['Eric Frenzel', '==World Cup==']
# ['Eric Frenzel', '==World Cup==', '===Standings===']
# ['Eric Frenzel', '==World Cup==', '===Individual victories===']
# ['Mexico at the 2022 Winter Olympics', '==Competitors==']
# ['Mexico at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Mexico at the 2022 Winter Olympics', '==Cross-country skiing==']
# ['Mexico at the 2022 Winter Olympics', '==Figure skating==']
# ['Timi Zajc', '==Career==']
# ['Timi Zajc', '==Career==', '===Continental Cup===']
# ['Timi Zajc', '==Career==', '===World Cup debut===']
# ['Timi Zajc', '==Major tournament results==']
# ['Timi Zajc', '==Major tournament results==', '===Winter Olympics===']
# ['Timi Zajc', '==Major tournament results==', '===FIS Nordic World Ski Championships===']
# ['Timi Zajc', '==Major tournament results==', '===FIS Ski Flying World Championships===']
# ['Timi Zajc', '==World Cup results==']
# ['Timi Zajc', '==World Cup results==', '===Standings===']
# ['Timi Zajc', '==World Cup results==', '===Individual wins===']
# ['Timi Zajc', '==World Cup results==', '===Individual starts===']
# ['Ashton Bell', '== Career ==']
# ['Ashton Bell', '== International career ==']
# ['Ashton Bell', '== Personal life ==']
# ['Irina Kazakevich', '==Biathlon results==']
# ['Irina Kazakevich', '==Biathlon results==', '===Olympic Games===']
# ['Irina Kazakevich', '==Biathlon results==', '===World Championships===']
# ['Mikhail Grigorenko', '==Playing career==']
# ['Mikhail Grigorenko', '==Playing career==', '===Junior===']
# ['Mikhail Grigorenko', '==Playing career==', '===Professional===']
# ['Mikhail Grigorenko', '==Playing career==', '===Professional===', '====Buffalo Sabres====']
# ['Mikhail Grigorenko', '==Playing career==', '===Professional===', '====Colorado Avalanche====']
# ['Mikhail Grigorenko', '==Playing career==', '===Professional===', '====CSKA Moscow====']
# ['Mikhail Grigorenko', '==Playing career==', '===Professional===', '==== Columbus Blue Jackets ====']
# ['Mikhail Grigorenko', '==Playing career==', '===Professional===', '====Return to CSKA====']
# ['Mikhail Grigorenko', '==International play==']
# ['Mikhail Grigorenko', '==Personal life==']
# ['Mikhail Grigorenko', '==Career statistics==']
# ['Mikhail Grigorenko', '==Career statistics==', '===Regular season and playoffs===']
# ['Mikhail Grigorenko', '==Career statistics==', '===International===']
# ['Mikhail Grigorenko', '==Awards and honours==']
# ['Oleksandr Abramenko', '==Career==']
# ['Oleksandr Abramenko', '==Personal life==']
# ['Oleksandr Abramenko', '==Career results==']
# ['Oleksandr Abramenko', '==Career results==', '===Winter Olympics===']
# ['Oleksandr Abramenko', '==Career results==', '===World Championships===']
# ['Oleksandr Abramenko', '==Career results==', '===World Cup===']
# ['Oleksandr Abramenko', '==Career results==', '===World Cup===', '====Individual podiums====']
# ['Oleksandr Abramenko', '==Career results==', '===World Cup===', '====Team podiums====']
# ['Oleksandr Abramenko', '==Career results==', '===World Cup===', '====Individual rankings====']
# ['Oleksandr Abramenko', '==Career results==', '===European Cup===']
# ['Oleksandr Abramenko', '==Career results==', '===European Cup===', '====Individual podiums====']
# ['Marijke Groenewoud', '==Career==']
# ['Marijke Groenewoud', '==Records==']
# ['Marijke Groenewoud', '==Records==', '===Personal records===']
# ['Marijke Groenewoud', '==Tournament overview==']
# ['Marijke Groenewoud', '==World Cup overview==']
# ['Joni Mäki', '==Career==']
# ['Joni Mäki', '==Cross-country skiing results==']
# ['Joni Mäki', '==Cross-country skiing results==', '===Olympic Games===']
# ['Joni Mäki', '==Cross-country skiing results==', '===World Championships===']
# ['Joni Mäki', '==Cross-country skiing results==', '===World Cup===']
# ['Joni Mäki', '==Cross-country skiing results==', '===World Cup===', '====Season standings====']
# ['Joni Mäki', '==Cross-country skiing results==', '===World Cup===', '====Individual podiums====']
# ['Joni Mäki', '==Cross-country skiing results==', '===World Cup===', '====Team podiums====']
# ['Miha Fontaine', '==Career==']
# ['Miha Fontaine', '==Career==', '===Winter Olympics medalist===']
# ['Bids for the 2022 Winter Olympics', '==Bidding calendar==']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities venues list==']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities venues list==', '===Withdrawn candidate city===']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities comparison==']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities comparison==', '===Withdrawn candidate city===']
# ['Bids for the 2022 Winter Olympics', '==Evaluation of the applicant cities==']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities overview==']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities overview==', '===Almaty===']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities overview==', '===Beijing===']
# ['Bids for the 2022 Winter Olympics', '==Candidate cities overview==', '===Oslo===']
# ['Bids for the 2022 Winter Olympics', '== Applicant cities overview==']
# ['Bids for the 2022 Winter Olympics', '==Voting results for the 2022 Winter Olympics and Paralympics==']
# ['Bids for the 2022 Winter Olympics', '==Previously interested in bidding==']
# ['Emily Clark (ice hockey)', '==Early life==']
# ['Emily Clark (ice hockey)', '==Playing career==']
# ['Emily Clark (ice hockey)', '==Playing career==', '===Hockey Canada===']
# ['Emily Clark (ice hockey)', '==Playing career==', '===NCAA===']
# ['Emily Clark (ice hockey)', '==Playing career==', '===2018 Winter Olympics===']
# ['Emily Clark (ice hockey)', '==Playing career==', '===2022 Winter Olympics===']
# ['Emily Clark (ice hockey)', '==Career statistics==']
# ['Emily Clark (ice hockey)', '==Career statistics==', '=== Regular Season and Playoffs ===']
# ['Emily Clark (ice hockey)', '==Career statistics==', '=== International ===']
# ['Emily Clark (ice hockey)', '==Awards and honours==']
# ['Emily Clark (ice hockey)', '== Personal life ==']
# ['2020–21 figure skating season', '== Impact of the COVID-19 pandemic ==']
# ['2020–21 figure skating season', '== Impact of the COVID-19 pandemic ==', "=== ISU member nations' response ==="]
# ['2020–21 figure skating season', '== Impact of the COVID-19 pandemic ==', "=== ISU member nations' response ===", '==== National championships ====']
# ['2020–21 figure skating season', '== Season notes ==']
# ['2020–21 figure skating season', '== Season notes ==', '=== Age eligibility ===']
# ['2020–21 figure skating season', '== Changes ==']
# ['2020–21 figure skating season', '== Changes ==', '=== Partnership changes ===']
# ['2020–21 figure skating season', '== Changes ==', '=== Retirements ===']
# ['2020–21 figure skating season', '== Changes ==', '=== Coaching changes ===']
# ['2020–21 figure skating season', '== Changes ==', '=== Nationality changes ===']
# ['2020–21 figure skating season', '== Competitions ==']
# ['2020–21 figure skating season', '== Competitions ==', '=== Cancelled and postponed events ===']
# ['2020–21 figure skating season', '== International medalists ==']
# ['2020–21 figure skating season', '== International medalists ==', '=== Men ===']
# ['2020–21 figure skating season', '== International medalists ==', '=== Ladies ===']
# ['2020–21 figure skating season', '== International medalists ==', '=== Pairs ===']
# ['2020–21 figure skating season', '== International medalists ==', '=== Ice dance ===']
# ['2020–21 figure skating season', "== Season's best scores =="]
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Men ===']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Men ===', '==== Best total score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Men ===', '==== Best short program score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Men ===', '==== Best free skating score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ladies ===']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ladies ===', '==== Best total score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ladies ===', '==== Best short program score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ladies ===', '==== Best free skating score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Pairs ===']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Pairs ===', '====Best total score====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Pairs ===', '==== Best short program score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Pairs ===', '==== Best free skating score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ice dance ===']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ice dance ===', '==== Best total score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ice dance ===', '==== Best rhythm dance score ====']
# ['2020–21 figure skating season', "== Season's best scores ==", '=== Ice dance ===', '==== Best free dance score ====']
# ['2020–21 figure skating season', '== Standings and ranking ==']
# ['2020–21 figure skating season', '== Standings and ranking ==', '=== Current standings (top 30) ===']
# ['2020–21 figure skating season', '== Standings and ranking ==', '=== Current standings (top 30) ===', '==== Men ====']
# ['2020–21 figure skating season', '== Standings and ranking ==', '=== Current standings (top 30) ===', '==== Ladies ====']
# ['2020–21 figure skating season', '== Standings and ranking ==', '=== Current standings (top 30) ===', '==== Pairs ====']
# ['2020–21 figure skating season', '== Standings and ranking ==', '=== Current standings (top 30) ===', '==== Ice dance ====']
# ["Meryeta O'Dine", '==Career==']
# ["Meryeta O'Dine", '==Career==', '===Early career===']
# ["Meryeta O'Dine", '==Career==', '===2022 Winter Olympics===']
# ["Meryeta O'Dine", '==Personal life==']
# ['Brianna Decker', '==Playing career==']
# ['Brianna Decker', '==Playing career==', '===NCAA===']
# ['Brianna Decker', '==Playing career==', '===USA Hockey===']
# ['Brianna Decker', '==Playing career==', '===Professional===']
# ['Brianna Decker', '==Playing career==', '===Professional===', '====CWHL====']
# ['Brianna Decker', '==Playing career==', '===Professional===', '====NWHL====']
# ['Brianna Decker', '==Playing career==', '===Professional===', '====Return to CWHL====']
# ['Brianna Decker', '==Playing career==', '===Professional===', '====NHL====']
# ['Brianna Decker', '==Playing career==', '===PWHPA===']
# ['Brianna Decker', '==Career statistics==']
# ['Brianna Decker', '==Career statistics==', '===NCAA===']
# ['Brianna Decker', '==Career statistics==', '===NCAA===', '====WCHA====']
# ['Brianna Decker', '==Career statistics==', '===CWHL===']
# ['Brianna Decker', '==Career statistics==', '===NWHL===']
# ['Brianna Decker', '==Awards and honors==']
# ['Brianna Decker', '==Awards and honors==', '===NCAA===']
# ['Brianna Decker', '==Awards and honors==', '===CWHL===']
# ['Brianna Decker', '==Awards and honors==', '===IIHF===']
# ['Brianna Decker', '==Awards and honors==', '===NWHL===']
# ['Cene Prevc', '== Career ==']
# ['Cene Prevc', '==Personal life==']
# ['Cene Prevc', '== World Cup ==']
# ['Cene Prevc', '== World Cup ==', '=== Standings ===']
# ['Cene Prevc', '== World Cup ==', '=== Individual starts ===']
# ['Mark McMorris', '==Career==']
# ['Mark McMorris', '==Career==', '=== Early career ===']
# ['Mark McMorris', '==Career==', '===2014 X-Games & Olympics===']
# ['Mark McMorris', '==Career==', '===Injuries===']
# ['Mark McMorris', '==Career==', '=== 2018 Winter Olympics ===']
# ['Mark McMorris', '==Career==', '=== 2022 Winter Olympics and 2023 X-Games ===']
# ['Mark McMorris', '==Personal life==']
# ['Brittany Bowe', '==Early life==']
# ['Brittany Bowe', '==Inline speed skating==']
# ['Brittany Bowe', '==Basketball==']
# ['Brittany Bowe', '==Basketball==', '=== Florida Atlantic statistics===']
# ['Brittany Bowe', '==Speed skating==']
# ['Brittany Bowe', '==Speed skating==', '===Records===']
# ['Brittany Bowe', '==Speed skating==', '===Records===', '====Personal records====']
# ['Brittany Bowe', '==Speed skating==', '===Records===', '====World records====']
# ['Brittany Bowe', '==Speed skating==', '===Results timeline===']
# ['Jørgen Graabak', '==Biography==']
# ['Jørgen Graabak', '==Career==']
# ['Jørgen Graabak', '==Record==']
# ['Jørgen Graabak', '==Record==', '===Olympic Games===']
# ['Jørgen Graabak', '==Record==', '===World Championship===']
# ['Anastasia Smirnova (freestyle skier)', '==Career==']
# ['Anastasia Smirnova (freestyle skier)', '==World Cup podiums==']
# ['Anastasia Smirnova (freestyle skier)', '==World Cup podiums==', '===Individual podiums===']
# ['2022 Winter Olympics marketing', '==Symbols==']
# ['2022 Winter Olympics marketing', '==Symbols==', '===Emblem===']
# ['2022 Winter Olympics marketing', '==Symbols==', '===Slogan===']
# ['2022 Winter Olympics marketing', '==Symbols==', '===Mascot===']
# ['2022 Winter Olympics marketing', '== Corporate sponsorship ==']
# ['Peter Cehlárik', '==Playing career ==']
# ['Peter Cehlárik', '==Career statistics==']
# ['Peter Cehlárik', '==Career statistics==', '===Regular season and playoffs===']
# ['Peter Cehlárik', '==Career statistics==', '===International===']
# ['Peter Cehlárik', '==Awards and honours==']
# ['Claire Thompson (ice hockey)', '==Playing career==']
# ['Claire Thompson (ice hockey)', '==Playing career==', '===Hockey Canada===']
# ['Claire Thompson (ice hockey)', '==Playing career==', '=== University ===']
# ['Claire Thompson (ice hockey)', '==Playing career==', '=== Medical School ===']
# ['Claire Thompson (ice hockey)', '==Career statistics==']
# ['Claire Thompson (ice hockey)', '==Career statistics==', '===Regular season and playoffs===']
# ['Claire Thompson (ice hockey)', '==Career statistics==', '===International===']
# ['Claire Thompson (ice hockey)', '==Awards and honours==']
# ['Satsuki Fujisawa', '==Career==']
# ['Satsuki Fujisawa', '==Career==', '===Mixed doubles===']
# ['Satsuki Fujisawa', '==Personal life==']
# ['Satsuki Fujisawa', '==Grand Slam record==']
# ['Satsuki Fujisawa', '==Grand Slam record==', '===Former events===']
# ['Satsuki Fujisawa', '==Teams==']
# ['Satsuki Fujisawa', '==Teams==', "===Women's==="]
# ['Satsuki Fujisawa', '==Teams==', '===Mixed doubles===']
# ['Yumi Suzuki', '==Career==']
# ['Yumi Suzuki', '==Personal life==']
# ['Yumi Suzuki', '==Teams==']
# ['Renata Fast', '==Playing career==']
# ['Renata Fast', '==Playing career==', '===NCAA===']
# ['Renata Fast', '==Playing career==', '===Hockey Canada===']
# ['Renata Fast', '==Playing career==', '===CWHL===']
# ['Renata Fast', '== Personal Life ==']
# ['Renata Fast', '== Career Statistics ==']
# ['Renata Fast', '== Career Statistics ==', '=== Regular Season and Playoffs ===']
# ['Renata Fast', '== Career Statistics ==', '=== International ===']
# ['Renata Fast', '==Awards and honours==']
# ['Renata Fast', '==Awards and honours==', '===NCAA===']
# ['Renata Fast', '==Awards and honours==', '===CWHL===']
# ['Renata Fast', '==Awards and honours==', '===Burlington Sport Alliance===']
# ['Renata Fast', '==Awards and honours==', '===IIHF===']
# ['Renata Fast', '==Awards and honours==', '===Olympics===']
# ['Alessandro Hämmerle', '==World Cup podiums==']
# ['Wakaba Higuchi', '==Personal life==']
# ['Wakaba Higuchi', '==Career==']
# ['Wakaba Higuchi', '==Career==', '=== Early career ===']
# ['Wakaba Higuchi', '==Career==', '=== 2014–2015 season: World Junior bronze ===']
# ['Wakaba Higuchi', '==Career==', '=== 2015–2016 season: Second World Junior bronze ===']
# ['Wakaba Higuchi', '==Career==', '=== 2016–2017 season: Senior debut ===']
# ['Wakaba Higuchi', '==Career==', '=== 2017–2018 season: World silver ===']
# ['Wakaba Higuchi', '==Career==', '=== 2018–2019 season: Injury struggles ===']
# ['Wakaba Higuchi', '==Career==', '=== 2019–2020 season: Comeback ===']
# ['Wakaba Higuchi', '==Career==', '=== 2020–2021 season ===']
# ['Wakaba Higuchi', '==Career==', '=== 2021–2022 season: Beijing Olympics ===']
# ['Wakaba Higuchi', '==Career==', '===2022–2023 season===']
# ['Wakaba Higuchi', '== Programs ==']
# ['Wakaba Higuchi', '== Competitive highlights ==']
# ['Wakaba Higuchi', '== Detailed results ==']
# ['Wakaba Higuchi', '== Detailed results ==', '=== Senior level ===']
# ['Wakaba Higuchi', '== Detailed results ==', '=== Junior level ===']
# ['Emery Lehman', '==Early and personal life==']
# ['Emery Lehman', '==Athletic career==']
# ['Emery Lehman', '==Athletic career==', '===Ice hockey===']
# ['Emery Lehman', '==Athletic career==', '===Speed skating===']
# ['Emery Lehman', '==Athletic career==', '===Lacrosse===']
# ['Emery Lehman', '==Personal bests==']
# ['Croatia at the 2022 Winter Olympics', '==Competitors==']
# ['Croatia at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Croatia at the 2022 Winter Olympics', '==Cross-country skiing==']
# ['Croatia at the 2022 Winter Olympics', '==Short track speed skating==']
# ['Croatia at the 2022 Winter Olympics', '==Snowboarding==']
# ['Anna Berreiter', '==Career==']
# ['Anna Berreiter', '==Career==', '===Youth and junior career===']
# ['Anna Berreiter', '==Career==', '===Senior career===']
# ['Anna Berreiter', '==Career==', '===Senior career===', '====2019/20 season: World Cup debut and first victory====']
# ['Anna Berreiter', '==Luge results==']
# ['Anna Berreiter', '==Luge results==', '===World Cup===']
# ['Anna Berreiter', '==Luge results==', '===European Championships===']
# ['Anna Berreiter', '==Luge results==', '===U23 World Championships===']
# ['Anna Berreiter', '==Luge results==', '===Junior World Championships===']
# ['Anna Berreiter', '==Luge results==', '===Junior European Championships===']
# ['Anna Berreiter', '==Luge results==', '===German Championships===']
# ['Angelina Golikova', '==Records==']
# ['Angelina Golikova', '==Records==', '===Personal records===']
# ['Angelina Golikova', '==World Cup podiums==']
# ['Angelina Golikova', '==World Cup podiums==', '===Overall rankings===']
# ['Peter Zuzin', '==Career==']
# ['Peter Zuzin', '==Career statistics==']
# ['Peter Zuzin', '==Career statistics==', '===Regular season and playoffs===']
# ['Peter Zuzin', '==Career statistics==', '===International===']
# ['Peter Zuzin', '==Awards and honors==']
# ['Saku Mäenalanen', '==Playing career==']
# ['Saku Mäenalanen', '==International play==']
# ['Saku Mäenalanen', '==Career statistics==']
# ['Saku Mäenalanen', '==Career statistics==', '===Regular season and playoffs===']
# ['Saku Mäenalanen', '==Career statistics==', '===International===']
# ['Saku Mäenalanen', '==Awards and honours==']
# ['India at the 2022 Winter Olympics', '==Boycott==']
# ['India at the 2022 Winter Olympics', '==Competitors==']
# ['India at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Alexander Samonov', '==International play==']
# ['Alexander Samonov', '==Career statistics==']
# ['Alexander Samonov', '==Career statistics==', '===Regular season and playoffs===']
# ['Alexander Samonov', '==Career statistics==', '===International===']
# ['Ice hockey at the 2022 Winter Olympics', '==Medal summary==']
# ['Ice hockey at the 2022 Winter Olympics', '==Medal summary==', '===Medal table===']
# ['Ice hockey at the 2022 Winter Olympics', '==Medal summary==', '===Medalists===']
# ['Ice hockey at the 2022 Winter Olympics', '==Venues==']
# ['Ice hockey at the 2022 Winter Olympics', '==Competition schedule==']
# ['Ice hockey at the 2022 Winter Olympics', "==Men's tournament=="]
# ['Ice hockey at the 2022 Winter Olympics', "==Men's tournament==", '===Qualification===']
# ['Ice hockey at the 2022 Winter Olympics', "==Men's tournament==", '===Participating nations===']
# ['Ice hockey at the 2022 Winter Olympics', "==Women's tournament=="]
# ['Ice hockey at the 2022 Winter Olympics', "==Women's tournament==", '===Qualification===']
# ['Ice hockey at the 2022 Winter Olympics', "==Women's tournament==", '===Participating nations===']
# ['Ice hockey at the 2022 Winter Olympics', "==Qualification summary / Participating NOC's=="]
# ['Vetle Sjåstad Christiansen', '==Early life==']
# ['Vetle Sjåstad Christiansen', '==Career==']
# ['Vetle Sjåstad Christiansen', '==Career==', '===Early career and World Cup debut===']
# ['Vetle Sjåstad Christiansen', '==Career==', '===Olympic season (2013–14 World Cup season)===']
# ['Vetle Sjåstad Christiansen', '==Career==', '===Stagnation and illness (2014–15 World Cup season)===']
# ['Vetle Sjåstad Christiansen', '==Career==', '===Leaving the national team (2015–16 World Cup season)===']
# ['Vetle Sjåstad Christiansen', '==Biathlon results==']
# ['Vetle Sjåstad Christiansen', '==Biathlon results==', '===Olympic Games===']
# ['Vetle Sjåstad Christiansen', '==Biathlon results==', '===World Championships===']
# ['Vetle Sjåstad Christiansen', '==Biathlon results==', '===Junior/Youth World Championships===']
# ['Vetle Sjåstad Christiansen', '==Biathlon results==', '===Biathlon World Cup===']
# ['Vetle Sjåstad Christiansen', '==Biathlon results==', '===Biathlon World Cup===', '====Individual victories (3)====']
# ['Nordic combined at the 2022 Winter Olympics – Qualification', '==Qualification==']
# ['Nordic combined at the 2022 Winter Olympics – Qualification', '==Quota allocation==']
# ['Nordic combined at the 2022 Winter Olympics – Qualification', '==Quota allocation==', '===Summary===']
# ['Nordic combined at the 2022 Winter Olympics – Qualification', '==Quota allocation==', '===Next eligible NOC===']
# ['Almida de Val', '==Career==']
# ['Almida de Val', '==Grand Slam record==']
# ['Almida de Val', '==Teams==']
# ['Timor Leste at the 2022 Winter Olympics', '==Competitors==']
# ['Timor Leste at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Bobby Lammie', '==Career==']
# ['Bobby Lammie', '==Career==', '===Juniors===']
# ['Bobby Lammie', '==Career==', '===Mixed===']
# ['Bobby Lammie', '==Career==', "===Men's==="]
# ['Bobby Lammie', '==Personal life==']
# ['Jessie Diggins', '==Early life==']
# ['Jessie Diggins', '==Athletic career==']
# ['Jessie Diggins', '==Athletic career==', '===High school and juniors===']
# ['Jessie Diggins', '==Athletic career==', '===Professional===']
# ['Jessie Diggins', '==Social activism==']
# ['Jessie Diggins', '==Cross-country skiing results==']
# ['Jessie Diggins', '==Cross-country skiing results==', '===Olympic Games===']
# ['Jessie Diggins', '==Cross-country skiing results==', '===World Championships===']
# ['Jessie Diggins', '==Cross-country skiing results==', '===World Cup===']
# ['Jessie Diggins', '==Cross-country skiing results==', '===World Cup===', '====Season titles====']
# ['Jessie Diggins', '==Cross-country skiing results==', '===World Cup===', '====Season standings====']
# ['Jessie Diggins', '==Cross-country skiing results==', '===World Cup===', '====Individual podiums====']
# ['Johannes Strolz', '== Biography ==']
# ['Johannes Strolz', '== Biography ==', '=== Youth and Europa Cup ===']
# ['Johannes Strolz', '== Biography ==', '=== World Cup and Olympic Games ===']
# ['Johannes Strolz', '==World Cup results==']
# ['Johannes Strolz', '==World Cup results==', '===Season standings===']
# ['Johannes Strolz', '==World Cup results==', '===Top ten finishes===']
# ['Johannes Strolz', '==World Championship results==']
# ['Johannes Strolz', '==Olympic results==']
# ['Ruslan Zakharov', '==Career==']
# ['Ruslan Zakharov', '==World Cup podiums==']
# ['Ruslan Zakharov', '==World Cup podiums==', '===Short track===']
# ['Ruslan Zakharov', '==World Cup podiums==', '===Long track===']
# ['Ruslan Zakharov', '==World Cup podiums==', '===Overall rankings===']
# ['Mathieu Faivre', '==Career==']
# ['Mathieu Faivre', '==Personal life==']
# ['Mathieu Faivre', '==World Cup results==']
# ['Mathieu Faivre', '==World Cup results==', '===Season standings===']
# ['Mathieu Faivre', '==World Cup results==', '===Race podiums===']
# ['Mathieu Faivre', '==World Championships results==']
# ['Mathieu Faivre', '==Olympic results==']
# ['Kyrgyzstan at the 2022 Winter Olympics', '==Competitors==']
# ['Kyrgyzstan at the 2022 Winter Olympics', '==Alpine skiing==']
# ['Jenni Hiirikoski', '== Playing career ==']
# ['Jenni Hiirikoski', '== Playing career ==', '=== Style of play ===']
# ['Jenni Hiirikoski', '== International career ==']
# ['Jenni Hiirikoski', '==Career statistics==']
# ['Jenni Hiirikoski', '==Career statistics==', '=== Regular season and playoffs ===']
# ['Jenni Hiirikoski', '==Career statistics==', '===International===']
# ['Jenni Hiirikoski', '==Honors and achievements==']
# ['Ecuador at the 2022 Winter Olympics', '==Competitors==']
# ['Ecuador at the 2022 Winter Olympics', '==Alpine skiing==']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 wikipedia_sections = []
#       4 for title in titles:
# ----> 5     wikipedia_sections.extend(all_subsections_from_title(title))
#       6 print(f"Found {len(wikipedia_sections)} sections in {len(titles)} pages.")
#
# Cell In[3], line 68, in all_subsections_from_title(title, sections_to_ignore, site_name)
#      66 site = mwclient.Site(site_name)
#      67 page = site.pages[title]
# ---> 68 text = page.text()
#      69 parsed_text = mwparserfromhell.parse(text)
#      70 headings = [str(h) for h in parsed_text.filter_headings()]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/page.py:157, in Page.text(self, section, expandtemplates, cache, slot)
#     154 revs = self.revisions(prop='content|timestamp', limit=1, section=section,
#     155                       slots=slot)
#     156 try:
# --> 157     rev = next(revs)
#     158     if 'slots' in rev:
#     159         text = rev['slots'][slot]['*']
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/listing.py:61, in List.__next__(self)
#      59         if self.last:
#      60             raise
# ---> 61         self.load_chunk()
#      63 self.count += 1
#      64 if 'timestamp' in item:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/listing.py:325, in RevisionsIterator.load_chunk(self)
#     323 if 'rvstartid' in self.args and 'rvstart' in self.args:
#     324     del self.args['rvstart']
# --> 325 return super(RevisionsIterator, self).load_chunk()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/listing.py:95, in List.load_chunk(self)
#      79 def load_chunk(self):
#      80     """Query a new chunk of data
#      81
#      82     If the query is empty, `raise StopIteration`.
#    (...)
#      93     Else, set `self.last` to True.
#      94     """
# ---> 95     data = self.site.get(
#      96         'query', (self.generator, self.list_name),
#      97         *[(text_type(k), v) for k, v in six.iteritems(self.args)]
#      98     )
#      99     if not data:
#     100         # Non existent page
#     101         raise StopIteration
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:234, in Site.get(self, action, *args, **kwargs)
#     225 def get(self, action, *args, **kwargs):
#     226     """Perform a generic API call using GET.
#     227
#     228     This is just a shorthand for calling api() with http_method='GET'.
#    (...)
#     232         The raw response from the API call, as a dictionary.
#     233     """
# --> 234     return self.api(action, 'GET', *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:285, in Site.api(self, action, http_method, *args, **kwargs)
#     282 sleeper = self.sleepers.make()
#     284 while True:
# --> 285     info = self.raw_api(action, http_method, **kwargs)
#     286     if not info:
#     287         info = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:437, in Site.raw_api(self, action, http_method, *args, **kwargs)
#     435 kwargs['format'] = 'json'
#     436 data = self._query_string(*args, **kwargs)
# --> 437 res = self.raw_call('api', data, retry_on_error=retry_on_error,
#     438                     http_method=http_method)
#     440 try:
#     441     return json.loads(res, object_pairs_hook=OrderedDict)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mwclient/client.py:399, in Site.raw_call(self, script, data, files, retry_on_error, http_method)
#     396 else:
#     397     args['data'] = data
# --> 399 stream = self.connection.request(http_method, url, **args)
#     401 if stream.headers.get('x-database-lag'):
#     402     wait_time = int(stream.headers.get('retry-after'))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# clean text
def clean_section(section: tuple[list[str], str]) -> tuple[list[str], str]:
    """
    Return a cleaned up section with:
        - <ref>xyz</ref> patterns removed
        - leading/trailing whitespace removed
    """
    titles, text = section
    text = re.sub(r"<ref.*?</ref>", "", text)
    text = text.strip()
    return (titles, text)


wikipedia_sections = [clean_section(ws) for ws in wikipedia_sections]

# filter out short/blank sections
def keep_section(section: tuple[list[str], str]) -> bool:
    """Return True if the section should be kept, False otherwise."""
    titles, text = section
    if len(text) < 16:
        return False
    else:
        return True


original_num_sections = len(wikipedia_sections)
wikipedia_sections = [ws for ws in wikipedia_sections if keep_section(ws)]
print(f"Filtered out {original_num_sections-len(wikipedia_sections)} sections, leaving {len(wikipedia_sections)} sections.")
# Out:
# Filtered out 530 sections, leaving 5200 sections.

# %%
# print example data
for ws in wikipedia_sections[:5]:
    print(ws[0])
    display(ws[1][:77] + "...")
    print()
# Out:
# ['Lviv bid for the 2022 Winter Olympics']
# '{{Olympic bid|2022|Winter|\n| Paralympics = yes\n| logo = Lviv 2022 Winter Olym...'
# ['Lviv bid for the 2022 Winter Olympics', '==History==']
# '[[Image:Lwów - Rynek 01.JPG|thumb|right|200px|View of Rynok Square in Lviv]]\n...'
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==']
# '{{Location map+\n|Ukraine\n|border =\n|caption = Venue areas\n|float = left\n|widt...'
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==', '===City zone===']
# 'The main Olympic Park would be centered around the [[Arena Lviv]], hosting th...'
# ['Lviv bid for the 2022 Winter Olympics', '==Venues==', '===Mountain zone===', '====Venue cluster Tysovets-Panasivka====']
# 'An existing military ski training facility in [[Tysovets, Skole Raion|Tysovet...'

# %% [markdown]
# Next, we'll recursively split long sections into smaller sections.
#
# There's no perfect recipe for splitting text into sections.
#
# Some tradeoffs include:
# - Longer sections may be better for questions that require more context
# - Longer sections may be worse for retrieval, as they may have more topics muddled together
# - Shorter sections are better for reducing costs (which are proportional to the number of tokens)
# - Shorter sections allow more sections to be retrieved, which may help with recall
# - Overlapping sections may help prevent answers from being cut by section boundaries
#
# Here, we'll use a simple approach and limit sections to 1,600 tokens each, recursively halving any sections that are too long. To avoid cutting in the middle of useful sentences, we'll split along paragraph boundaries when possible.

# %%
GPT_MODEL = "gpt-3.5-turbo"  # only matters insofar as it selects which tokenizer to use


def num_tokens(text: str, model: str = GPT_MODEL) -> int:
    """Return the number of tokens in a string."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))


def halved_by_delimiter(string: str, delimiter: str = "\n") -> list[str, str]:
    """Split a string in two, on a delimiter, trying to balance tokens on each side."""
    chunks = string.split(delimiter)
    if len(chunks) == 1:
        return [string, ""]  # no delimiter found
    elif len(chunks) == 2:
        return chunks  # no need to search for halfway point
    else:
        total_tokens = num_tokens(string)
        halfway = total_tokens // 2
        best_diff = halfway
        for i, chunk in enumerate(chunks):
            left = delimiter.join(chunks[: i + 1])
            left_tokens = num_tokens(left)
            diff = abs(halfway - left_tokens)
            if diff >= best_diff:
                break
            else:
                best_diff = diff
        left = delimiter.join(chunks[:i])
        right = delimiter.join(chunks[i:])
        return [left, right]


def truncated_string(
    string: str,
    model: str,
    max_tokens: int,
    print_warning: bool = True,
) -> str:
    """Truncate a string to a maximum number of tokens."""
    encoding = tiktoken.encoding_for_model(model)
    encoded_string = encoding.encode(string)
    truncated_string = encoding.decode(encoded_string[:max_tokens])
    if print_warning and len(encoded_string) > max_tokens:
        print(f"Warning: Truncated string from {len(encoded_string)} tokens to {max_tokens} tokens.")
    return truncated_string


def split_strings_from_subsection(
    subsection: tuple[list[str], str],
    max_tokens: int = 1000,
    model: str = GPT_MODEL,
    max_recursion: int = 5,
) -> list[str]:
    """
    Split a subsection into a list of subsections, each with no more than max_tokens.
    Each subsection is a tuple of parent titles [H1, H2, ...] and text (str).
    """
    titles, text = subsection
    string = "\n\n".join(titles + [text])
    num_tokens_in_string = num_tokens(string)
    # if length is fine, return string
    if num_tokens_in_string <= max_tokens:
        return [string]
    # if recursion hasn't found a split after X iterations, just truncate
    elif max_recursion == 0:
        return [truncated_string(string, model=model, max_tokens=max_tokens)]
    # otherwise, split in half and recurse
    else:
        titles, text = subsection
        for delimiter in ["\n\n", "\n", ". "]:
            left, right = halved_by_delimiter(text, delimiter=delimiter)
            if left == "" or right == "":
                # if either half is empty, retry with a more fine-grained delimiter
                continue
            else:
                # recurse on each half
                results = []
                for half in [left, right]:
                    half_subsection = (titles, half)
                    half_strings = split_strings_from_subsection(
                        half_subsection,
                        max_tokens=max_tokens,
                        model=model,
                        max_recursion=max_recursion - 1,
                    )
                    results.extend(half_strings)
                return results
    # otherwise no split was found, so just truncate (should be very rare)
    return [truncated_string(string, model=model, max_tokens=max_tokens)]

# %%
# split sections into chunks
MAX_TOKENS = 1600
wikipedia_strings = []
for section in wikipedia_sections:
    wikipedia_strings.extend(split_strings_from_subsection(section, max_tokens=MAX_TOKENS))

print(f"{len(wikipedia_sections)} Wikipedia sections split into {len(wikipedia_strings)} strings.")
# Out:
# 5200 Wikipedia sections split into 6059 strings.

# %%
# print example data
print(wikipedia_strings[1])
# Out:
# Lviv bid for the 2022 Winter Olympics
#
# ==History==
#
# [[Image:Lwów - Rynek 01.JPG|thumb|right|200px|View of Rynok Square in Lviv]]
#
# On 27 May 2010, [[President of Ukraine]] [[Viktor Yanukovych]] stated during a visit to [[Lviv]] that Ukraine "will start working on the official nomination of our country as the holder of the Winter Olympic Games in [[Carpathian Mountains|Carpathians]]".
#
# In September 2012, [[government of Ukraine]] approved a document about the technical-economic substantiation of the national project "Olympic Hope 2022". This was announced by Vladyslav Kaskiv, the head of Ukraine´s Derzhinvestproekt (State investment project). The organizers announced on their website venue plans featuring Lviv as the host city and location for the "ice sport" venues, [[Volovets]] (around {{convert|185|km|mi|abbr=on}} from Lviv) as venue for the [[Alpine skiing]] competitions and [[Tysovets, Skole Raion|Tysovets]] (around {{convert|130|km|mi|abbr=on}} from Lviv) as venue for all other "snow sport" competitions. By March 2013 no other preparations than the feasibility study had been approved.
#
# On 24 October 2013, session of the Lviv City Council adopted a resolution "About submission to the International Olympic Committee for nomination of city to participate in the procedure for determining the host city of Olympic and Paralympic Winter Games in 2022".
#
# On 5 November 2013, it was confirmed that Lviv was bidding to host the [[2022 Winter Olympics]]. Lviv would host the ice sport events, while the skiing events would be held in the [[Carpathian]] mountains. This was the first bid Ukraine had ever submitted for an Olympic Games.
#
# On 30 June 2014, the International Olympic Committee announced "Lviv will turn its attention to an Olympic bid for 2026, and not continue with its application for 2022. The decision comes as a result of the present political and economic circumstances in Ukraine."
#
# Ukraine's Deputy Prime Minister Oleksandr Vilkul said that the Winter Games "will be an impetus not just for promotion of sports and tourism in Ukraine, but a very important component in the economic development of Ukraine, the attraction of the investments, the creation of new jobs, opening Ukraine to the world, returning Ukrainians working abroad to their motherland."
#
# Lviv was one of the host cities of [[UEFA Euro 2012]].

# %% [markdown]
# ## 3. Embed document chunks
#
# Now that we've split our library into shorter self-contained strings, we can compute embeddings for each.
#
# (For large embedding jobs, use a script like [api_request_parallel_processor.py](api_request_parallel_processor.py) to parallelize requests while throttling to stay under rate limits.)

# %%
# calculate embeddings
EMBEDDING_MODEL = "text-embedding-ada-002"  # OpenAI's best embeddings as of Apr 2023
BATCH_SIZE = 1000  # you can submit up to 2048 embedding inputs per request

embeddings = []
for batch_start in range(0, len(wikipedia_strings), BATCH_SIZE):
    batch_end = batch_start + BATCH_SIZE
    batch = wikipedia_strings[batch_start:batch_end]
    print(f"Batch {batch_start} to {batch_end-1}")
    response = openai.Embedding.create(model=EMBEDDING_MODEL, input=batch)
    for i, be in enumerate(response["data"]):
        assert i == be["index"]  # double check embeddings are in same order as input
    batch_embeddings = [e["embedding"] for e in response["data"]]
    embeddings.extend(batch_embeddings)

df = pd.DataFrame({"text": wikipedia_strings, "embedding": embeddings})
# Out:
# Batch 0 to 999
# Batch 1000 to 1999
# Batch 2000 to 2999
# Batch 3000 to 3999
# Batch 4000 to 4999
# Batch 5000 to 5999
# Batch 6000 to 6999

# %% [markdown]
# ## 4. Store document chunks and embeddings
#
# Because this example only uses a few thousand strings, we'll store them in a CSV file.
#
# (For larger datasets, use a vector database, which will be more performant.)

# %%
# save document chunks and embeddings

SAVE_PATH = "data/winter_olympics_2022.csv"

df.to_csv(SAVE_PATH, index=False)
